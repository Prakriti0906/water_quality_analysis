# %% [markdown]
# # **Start**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Uninstall existing scikit-learn to avoid conflicts
# !pip uninstall -y scikit-learn
# Install specific versions of libraries to avoid conflicts
# !pip install scikit-learn==1.5.2
# !pip install bayesian-optimization
# !pip install optuna
# !pip install gpboost
# !pip install shap
# !pip install ngboost
# !pip install dask[dataframe]
# !pip install torch seaborn
# !pip install lightgbm
# !pip install xgboost
# !pip install lime
# !pip install interpret
# !pip install optunahub
# !pip install cmaes
# !pip install plotly kaleido
# !pip install openpyxl
# !pip install -U kaleido
# !pip install properscoring
# !pip install XlsxWriter
# !pip install cython
# !pip install pgbm
# !pip install torch
# !pip install cp
# !pip install mapie
# !pip install torch skorch puncc
# Reinstall scikit-learn to the version required by ngboost
# !pip uninstall -y scikit-learn
# !pip install scikit-learn==1.6.1
# Reinstall numpy first
# !pip install numpy==1.26.4  # Use the version compatible with catboost
# Reinstall catboost
# !pip install catboost
# Out:
# Found existing installation: scikit-learn 1.6.1
# Uninstalling scikit-learn-1.6.1:
#   Successfully uninstalled scikit-learn-1.6.1
# Collecting scikit-learn==1.5.2
#   Using cached scikit_learn-1.5.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.5.2) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.5.2) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.5.2) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.5.2) (3.6.0)
# Using cached scikit_learn-1.5.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.3 MB)
# Installing collected packages: scikit-learn
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ngboost 0.5.5 requires scikit-learn<2.0,>=1.6, but you have scikit-learn 1.5.2 which is incompatible.
# Successfully installed scikit-learn-1.5.2
# Requirement already satisfied: bayesian-optimization in /usr/local/lib/python3.11/dist-packages (2.0.3)
# Requirement already satisfied: colorama<0.5.0,>=0.4.6 in /usr/local/lib/python3.11/dist-packages (from bayesian-optimization) (0.4.6)
# Requirement already satisfied: numpy>=1.25 in /usr/local/lib/python3.11/dist-packages (from bayesian-optimization) (1.26.4)
# Requirement already satisfied: scikit-learn<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from bayesian-optimization) (1.5.2)
# Requirement already satisfied: scipy<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from bayesian-optimization) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<2.0.0,>=1.0.0->bayesian-optimization) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<2.0.0,>=1.0.0->bayesian-optimization) (3.6.0)
# Requirement already satisfied: optuna in /usr/local/lib/python3.11/dist-packages (4.3.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (1.15.2)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.40)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.13.2)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.1)
# Requirement already satisfied: gpboost in /usr/local/lib/python3.11/dist-packages (1.5.6)
# Requirement already satisfied: wheel in /usr/local/lib/python3.11/dist-packages (from gpboost) (0.45.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from gpboost) (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from gpboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from gpboost) (1.15.2)
# Requirement already satisfied: scikit-learn!=0.22.0 in /usr/local/lib/python3.11/dist-packages (from gpboost) (1.5.2)
# Requirement already satisfied: optuna in /usr/local/lib/python3.11/dist-packages (from gpboost) (4.3.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn!=0.22.0->gpboost) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn!=0.22.0->gpboost) (3.6.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from optuna->gpboost) (1.15.2)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna->gpboost) (6.9.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna->gpboost) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna->gpboost) (2.0.40)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna->gpboost) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna->gpboost) (6.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->gpboost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->gpboost) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->gpboost) (2025.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna->gpboost) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna->gpboost) (4.13.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->gpboost) (1.17.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna->gpboost) (3.2.1)
# Requirement already satisfied: shap in /usr/local/lib/python3.11/dist-packages (0.47.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from shap) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from shap) (1.15.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from shap) (1.5.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from shap) (2.2.2)
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/lib/python3.11/dist-packages (from shap) (4.67.1)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.11/dist-packages (from shap) (24.2)
# Requirement already satisfied: slicer==0.0.8 in /usr/local/lib/python3.11/dist-packages (from shap) (0.0.8)
# Requirement already satisfied: numba>=0.54 in /usr/local/lib/python3.11/dist-packages (from shap) (0.60.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from shap) (3.1.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from shap) (4.13.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.54->shap) (0.43.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->shap) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->shap) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->shap) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->shap) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->shap) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->shap) (1.17.0)
# Requirement already satisfied: ngboost in /usr/local/lib/python3.11/dist-packages (0.5.5)
# Requirement already satisfied: lifelines>=0.25 in /usr/local/lib/python3.11/dist-packages (from ngboost) (0.30.0)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from ngboost) (1.26.4)
# Collecting scikit-learn<2.0,>=1.6 (from ngboost)
#   Using cached scikit_learn-1.6.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Requirement already satisfied: scipy>=1.7.2 in /usr/local/lib/python3.11/dist-packages (from ngboost) (1.15.2)
# Requirement already satisfied: tqdm>=4.3 in /usr/local/lib/python3.11/dist-packages (from ngboost) (4.67.1)
# Requirement already satisfied: pandas>=2.1 in /usr/local/lib/python3.11/dist-packages (from lifelines>=0.25->ngboost) (2.2.2)
# Requirement already satisfied: matplotlib>=3.0 in /usr/local/lib/python3.11/dist-packages (from lifelines>=0.25->ngboost) (3.10.0)
# Requirement already satisfied: autograd>=1.5 in /usr/local/lib/python3.11/dist-packages (from lifelines>=0.25->ngboost) (1.7.0)
# Requirement already satisfied: autograd-gamma>=0.3 in /usr/local/lib/python3.11/dist-packages (from lifelines>=0.25->ngboost) (0.5.0)
# Requirement already satisfied: formulaic>=0.2.2 in /usr/local/lib/python3.11/dist-packages (from lifelines>=0.25->ngboost) (1.1.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<2.0,>=1.6->ngboost) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<2.0,>=1.6->ngboost) (3.6.0)
# Requirement already satisfied: interface-meta>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from formulaic>=0.2.2->lifelines>=0.25->ngboost) (1.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.11/dist-packages (from formulaic>=0.2.2->lifelines>=0.25->ngboost) (4.13.2)
# Requirement already satisfied: wrapt>=1.0 in /usr/local/lib/python3.11/dist-packages (from formulaic>=0.2.2->lifelines>=0.25->ngboost) (1.17.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0->lifelines>=0.25->ngboost) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0->lifelines>=0.25->ngboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0->lifelines>=0.25->ngboost) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0->lifelines>=0.25->ngboost) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0->lifelines>=0.25->ngboost) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0->lifelines>=0.25->ngboost) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0->lifelines>=0.25->ngboost) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0->lifelines>=0.25->ngboost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.1->lifelines>=0.25->ngboost) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.1->lifelines>=0.25->ngboost) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.0->lifelines>=0.25->ngboost) (1.17.0)
# Using cached scikit_learn-1.6.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.5 MB)
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.5.2
#     Uninstalling scikit-learn-1.5.2:
#       Successfully uninstalled scikit-learn-1.5.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mapie 0.9.2 requires scikit-learn<1.6.0, but you have scikit-learn 1.6.1 which is incompatible.
# Successfully installed scikit-learn-1.6.1
# Requirement already satisfied: dask[dataframe] in /usr/local/lib/python3.11/dist-packages (2024.12.1)
# Requirement already satisfied: click>=8.1 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]) (8.1.8)
# Requirement already satisfied: cloudpickle>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]) (3.1.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]) (2025.3.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]) (24.2)
# Requirement already satisfied: partd>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]) (6.0.2)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]) (0.12.1)
# Requirement already satisfied: importlib_metadata>=4.13.0 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]) (8.6.1)
# Requirement already satisfied: pandas>=2.0 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]) (2.2.2)
# Requirement already satisfied: dask-expr<1.2,>=1.1 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]) (1.1.21)
# Requirement already satisfied: pyarrow>=14.0.1 in /usr/local/lib/python3.11/dist-packages (from dask-expr<1.2,>=1.1->dask[dataframe]) (18.1.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib_metadata>=4.13.0->dask[dataframe]) (3.21.0)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0->dask[dataframe]) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0->dask[dataframe]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0->dask[dataframe]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0->dask[dataframe]) (2025.2)
# Requirement already satisfied: locket in /usr/local/lib/python3.11/dist-packages (from partd>=1.4.0->dask[dataframe]) (1.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=2.0->dask[dataframe]) (1.17.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.11/dist-packages (0.13.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /usr/local/lib/python3.11/dist-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.11/dist-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /usr/local/lib/python3.11/dist-packages (from seaborn) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.11/dist-packages (4.5.0)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from lightgbm) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from lightgbm) (1.15.2)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.11/dist-packages (2.1.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from xgboost) (1.26.4)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.11/dist-packages (from xgboost) (2.21.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from xgboost) (1.15.2)
# Requirement already satisfied: lime in /usr/local/lib/python3.11/dist-packages (0.2.0.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from lime) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from lime) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from lime) (1.15.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from lime) (4.67.1)
# Requirement already satisfied: scikit-learn>=0.18 in /usr/local/lib/python3.11/dist-packages (from lime) (1.6.1)
# Requirement already satisfied: scikit-image>=0.12 in /usr/local/lib/python3.11/dist-packages (from lime) (0.25.2)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.12->lime) (3.4.2)
# Requirement already satisfied: pillow>=10.1 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.12->lime) (11.2.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.12->lime) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.12->lime) (2025.3.30)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.12->lime) (24.2)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.12->lime) (0.4)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.18->lime) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.18->lime) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->lime) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->lime) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->lime) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->lime) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->lime) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->lime) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->lime) (1.17.0)
# Requirement already satisfied: interpret in /usr/local/lib/python3.11/dist-packages (0.6.10)
# Requirement already satisfied: interpret-core==0.6.10 in /usr/local/lib/python3.11/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (0.6.10)
# Requirement already satisfied: numpy>=1.25 in /usr/local/lib/python3.11/dist-packages (from interpret-core==0.6.10->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (1.26.4)
# Requirement already satisfied: pandas>=0.19.2 in /usr/local/lib/python3.11/dist-packages (from interpret-core==0.6.10->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (2.2.2)
# Requirement already satisfied: scikit-learn>=0.18.1 in /usr/local/lib/python3.11/dist-packages (from interpret-core==0.6.10->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (1.6.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.11/dist-packages (from interpret-core==0.6.10->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (1.4.2)
# Requirement already satisfied: psutil>=5.6.2 in /usr/local/lib/python3.11/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (5.9.5)
# Requirement already satisfied: ipykernel>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (6.17.1)
# Requirement already satisfied: ipython>=5.5.0 in /usr/local/lib/python3.11/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (7.34.0)
# Requirement already satisfied: plotly>=3.8.1 in /usr/local/lib/python3.11/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (5.24.1)
# Requirement already satisfied: SALib>=1.3.3 in /usr/local/lib/python3.11/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (1.5.1)
# Requirement already satisfied: shap>=0.28.5 in /usr/local/lib/python3.11/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (0.47.2)
# Requirement already satisfied: dill>=0.2.5 in /usr/local/lib/python3.11/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (0.4.0)
# Requirement already satisfied: aplr>=10.6.1 in /usr/local/lib/python3.11/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (10.9.0)
# Requirement already satisfied: dash<3.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (2.18.2)
# Requirement already satisfied: dash-core-components>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (2.0.0)
# Requirement already satisfied: dash-html-components>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (2.0.0)
# Requirement already satisfied: dash-table>=4.1.0 in /usr/local/lib/python3.11/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (5.0.0)
# Requirement already satisfied: dash-cytoscape>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (1.0.2)
# Requirement already satisfied: gevent>=1.3.6 in /usr/local/lib/python3.11/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (25.4.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (2.32.3)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in /usr/local/lib/python3.11/dist-packages (from dash<3.0.0,>=1.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (3.0.3)
# Requirement already satisfied: Werkzeug<3.1 in /usr/local/lib/python3.11/dist-packages (from dash<3.0.0,>=1.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (3.0.6)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.11/dist-packages (from dash<3.0.0,>=1.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (8.6.1)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.11/dist-packages (from dash<3.0.0,>=1.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (4.13.2)
# Requirement already satisfied: retrying in /usr/local/lib/python3.11/dist-packages (from dash<3.0.0,>=1.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (1.3.4)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.11/dist-packages (from dash<3.0.0,>=1.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (1.6.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from dash<3.0.0,>=1.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (75.2.0)
# Requirement already satisfied: greenlet>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from gevent>=1.3.6->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (3.2.1)
# Requirement already satisfied: zope.event in /usr/local/lib/python3.11/dist-packages (from gevent>=1.3.6->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (5.0)
# Requirement already satisfied: zope.interface in /usr/local/lib/python3.11/dist-packages (from gevent>=1.3.6->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (7.2)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.10.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (1.8.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.10.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (6.1.12)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.10.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (0.1.7)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.10.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (24.2)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.10.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (24.0.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.10.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (6.4.2)
# Requirement already satisfied: traitlets>=5.1.0 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.10.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (5.7.1)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (3.0.51)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (2.19.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (4.9.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.19.2->interpret-core==0.6.10->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.19.2->interpret-core==0.6.10->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.19.2->interpret-core==0.6.10->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (2025.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly>=3.8.1->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (9.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (2025.1.31)
# Requirement already satisfied: matplotlib>=3.5 in /usr/local/lib/python3.11/dist-packages (from SALib>=1.3.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (3.10.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.11/dist-packages (from SALib>=1.3.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (0.70.18)
# Requirement already satisfied: scipy>=1.9.3 in /usr/local/lib/python3.11/dist-packages (from SALib>=1.3.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (1.15.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.18.1->interpret-core==0.6.10->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (3.6.0)
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/lib/python3.11/dist-packages (from shap>=0.28.5->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (4.67.1)
# Requirement already satisfied: slicer==0.0.8 in /usr/local/lib/python3.11/dist-packages (from shap>=0.28.5->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (0.0.8)
# Requirement already satisfied: numba>=0.54 in /usr/local/lib/python3.11/dist-packages (from shap>=0.28.5->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (0.60.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from shap>=0.28.5->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (3.1.1)
# Requirement already satisfied: Jinja2>=3.1.2 in /usr/local/lib/python3.11/dist-packages (from Flask<3.1,>=1.0.4->dash<3.0.0,>=1.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (3.1.6)
# Requirement already satisfied: itsdangerous>=2.1.2 in /usr/local/lib/python3.11/dist-packages (from Flask<3.1,>=1.0.4->dash<3.0.0,>=1.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.11/dist-packages (from Flask<3.1,>=1.0.4->dash<3.0.0,>=1.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (8.1.8)
# Requirement already satisfied: blinker>=1.6.2 in /usr/local/lib/python3.11/dist-packages (from Flask<3.1,>=1.0.4->dash<3.0.0,>=1.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (1.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (0.8.4)
# Requirement already satisfied: jupyter-core>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.10.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (5.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5->SALib>=1.3.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5->SALib>=1.3.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5->SALib>=1.3.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5->SALib>=1.3.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5->SALib>=1.3.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5->SALib>=1.3.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (3.2.3)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.54->shap>=0.28.5->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (0.43.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (0.2.13)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=0.19.2->interpret-core==0.6.10->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from Werkzeug<3.1->dash<3.0.0,>=1.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (3.0.2)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata->dash<3.0.0,>=1.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (3.21.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.11/dist-packages (from jupyter-core>=4.6.0->jupyter-client>=6.1.12->ipykernel>=4.10.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret) (4.3.7)
# Requirement already satisfied: optunahub in /usr/local/lib/python3.11/dist-packages (0.2.0)
# Requirement already satisfied: ga4mp in /usr/local/lib/python3.11/dist-packages (from optunahub) (2.0.4)
# Requirement already satisfied: optuna in /usr/local/lib/python3.11/dist-packages (from optunahub) (4.3.0)
# Requirement already satisfied: PyGithub>=1.59 in /usr/local/lib/python3.11/dist-packages (from optunahub) (2.6.1)
# Requirement already satisfied: pynacl>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from PyGithub>=1.59->optunahub) (1.5.0)
# Requirement already satisfied: requests>=2.14.0 in /usr/local/lib/python3.11/dist-packages (from PyGithub>=1.59->optunahub) (2.32.3)
# Requirement already satisfied: pyjwt>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from pyjwt[crypto]>=2.4.0->PyGithub>=1.59->optunahub) (2.10.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from PyGithub>=1.59->optunahub) (4.13.2)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from PyGithub>=1.59->optunahub) (2.4.0)
# Requirement already satisfied: Deprecated in /usr/local/lib/python3.11/dist-packages (from PyGithub>=1.59->optunahub) (1.2.18)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from optuna->optunahub) (1.15.2)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna->optunahub) (6.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna->optunahub) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna->optunahub) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna->optunahub) (2.0.40)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna->optunahub) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna->optunahub) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna->optunahub) (1.1.3)
# Requirement already satisfied: cryptography>=3.4.0 in /usr/local/lib/python3.11/dist-packages (from pyjwt[crypto]>=2.4.0->PyGithub>=1.59->optunahub) (43.0.3)
# Requirement already satisfied: cffi>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from pynacl>=1.4.0->PyGithub>=1.59->optunahub) (1.17.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.14.0->PyGithub>=1.59->optunahub) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.14.0->PyGithub>=1.59->optunahub) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.14.0->PyGithub>=1.59->optunahub) (2025.1.31)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna->optunahub) (3.2.1)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.11/dist-packages (from Deprecated->PyGithub>=1.59->optunahub) (1.17.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.4.1->pynacl>=1.4.0->PyGithub>=1.59->optunahub) (2.22)
# Requirement already satisfied: cmaes in /usr/local/lib/python3.11/dist-packages (0.11.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from cmaes) (1.26.4)
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (5.24.1)
# Requirement already satisfied: kaleido in /usr/local/lib/python3.11/dist-packages (0.2.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly) (9.1.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from plotly) (24.2)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.11/dist-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.11/dist-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: kaleido in /usr/local/lib/python3.11/dist-packages (0.2.1)
# Requirement already satisfied: properscoring in /usr/local/lib/python3.11/dist-packages (0.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from properscoring) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from properscoring) (1.15.2)
# Requirement already satisfied: XlsxWriter in /usr/local/lib/python3.11/dist-packages (3.2.3)
# Requirement already satisfied: cython in /usr/local/lib/python3.11/dist-packages (3.0.12)
# Requirement already satisfied: pgbm in /usr/local/lib/python3.11/dist-packages (2.3.0)
# Requirement already satisfied: scikit-learn>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from pgbm) (1.6.1)
# Requirement already satisfied: ninja>=1.10.2.2 in /usr/local/lib/python3.11/dist-packages (from pgbm) (1.11.1.4)
# Requirement already satisfied: numba>=0.56 in /usr/local/lib/python3.11/dist-packages (from pgbm) (0.60.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.56->pgbm) (0.43.0)
# Requirement already satisfied: numpy<2.1,>=1.22 in /usr/local/lib/python3.11/dist-packages (from numba>=0.56->pgbm) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.2.0->pgbm) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.2.0->pgbm) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.2.0->pgbm) (3.6.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: cp in /usr/local/lib/python3.11/dist-packages (2020.12.3)
# Requirement already satisfied: mapie in /usr/local/lib/python3.11/dist-packages (0.9.2)
# Collecting scikit-learn<1.6.0 (from mapie)
#   Using cached scikit_learn-1.5.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from mapie) (1.15.2)
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.11/dist-packages (from mapie) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from mapie) (24.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<1.6.0->mapie) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<1.6.0->mapie) (3.6.0)
# Using cached scikit_learn-1.5.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.3 MB)
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.6.1
#     Uninstalling scikit-learn-1.6.1:
#       Successfully uninstalled scikit-learn-1.6.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ngboost 0.5.5 requires scikit-learn<2.0,>=1.6, but you have scikit-learn 1.5.2 which is incompatible.
# Successfully installed scikit-learn-1.5.2
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: skorch in /usr/local/lib/python3.11/dist-packages (1.1.0)
# Requirement already satisfied: puncc in /usr/local/lib/python3.11/dist-packages (0.8.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.11/dist-packages (from skorch) (1.26.4)
# Requirement already satisfied: scikit-learn>=0.22.0 in /usr/local/lib/python3.11/dist-packages (from skorch) (1.5.2)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from skorch) (1.15.2)
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.11/dist-packages (from skorch) (0.9.0)
# Requirement already satisfied: tqdm>=4.14.0 in /usr/local/lib/python3.11/dist-packages (from skorch) (4.67.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from puncc) (1.4.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from puncc) (3.10.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from puncc) (2.2.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.22.0->skorch) (3.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->puncc) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->puncc) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->puncc) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->puncc) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->puncc) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->puncc) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->puncc) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->puncc) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->puncc) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->puncc) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->puncc) (1.17.0)
# Found existing installation: scikit-learn 1.5.2
# Uninstalling scikit-learn-1.5.2:
#   Successfully uninstalled scikit-learn-1.5.2
# Collecting scikit-learn==1.6.1
#   Using cached scikit_learn-1.6.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.6.1) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.6.1) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.6.1) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.6.1) (3.6.0)
# Using cached scikit_learn-1.6.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.5 MB)
# Installing collected packages: scikit-learn
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mapie 0.9.2 requires scikit-learn<1.6.0, but you have scikit-learn 1.6.1 which is incompatible.
# Successfully installed scikit-learn-1.6.1
# Requirement already satisfied: numpy==1.26.4 in /usr/local/lib/python3.11/dist-packages (1.26.4)
# Requirement already satisfied: catboost in /usr/local/lib/python3.11/dist-packages (1.2.8)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.11/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from catboost) (3.10.0)
# Requirement already satisfied: numpy<3.0,>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.11/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from catboost) (1.15.2)
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from catboost) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (3.2.3)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly->catboost) (9.1.2)

# %%
# Restart the runtime to apply changes
import os
os._exit(00)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import ngboost
from scipy.stats import randint
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.base import BaseEstimator, RegressorMixin
from sklearn.svm import SVR
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
from gpboost import GPBoostRegressor
from ngboost import NGBRegressor
import optuna
import optunahub
from sklearn.experimental import enable_halving_search_cv
from sklearn.model_selection import HalvingGridSearchCV
from interpret import show
from interpret.blackbox import LimeTabular, ShapKernel
from optuna.samplers import RandomSampler
import random
import time
from ngboost.distns import Normal
from ngboost.scores import LogScore
from scipy.stats import norm
from interpret import set_visualize_provider
from interpret.provider import InlineProvider
from interpret.glassbox import ExplainableBoostingRegressor
from interpret import show
import plotly.express as px
from io import BytesIO
from openpyxl import Workbook, load_workbook
import os
from openpyxl.drawing.image import Image as openpyxlImage
import warnings
import xlsxwriter
from openpyxl.drawing.image import Image
from pgbm.sklearn import HistGradientBoostingRegressor
import torch
from pgbm.torch import PGBM
import plotly.graph_objects as go
warnings.filterwarnings('ignore')
import pickle
import json
# Out:
# No CUDA runtime is found, using CUDA_HOME='/usr/local/cuda'
# Using /root/.cache/torch_extensions/py311_cu124 as PyTorch extensions root...
# Emitting ninja build file /root/.cache/torch_extensions/py311_cu124/split_decision/build.ninja...
# Building extension module split_decision...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# Loading extension module split_decision...
# Using /root/.cache/torch_extensions/py311_cu124 as PyTorch extensions root...
# No modifications detected for re-loaded extension module split_decision, skipping build step...
# Loading extension module split_decision...

# %%
train_data_path = "./drive/MyDrive/water_analysis/train1.csv"
test_data_path = "./drive/MyDrive/water_analysis/test1.csv"
train_data = pd.read_csv(train_data_path)
test_data = pd.read_csv(test_data_path)
print("Training data loaded successfully.")
print("Test data loaded successfully.")
# Out:
# Training data loaded successfully.
# Test data loaded successfully.

# %%
print("\nShape of training data:", train_data.shape)
print("First 5 rows of training data:\n", train_data.head(5))
print("\nShape of test data:", test_data.shape)
print("First 5 rows of test data:\n", test_data.head(5))
# Out:
# Shape of training data: (47, 15)
# First 5 rows of training data:
#       pH   TDS    EC    TH   ca    mg  CO3  HCO3   NA    K  CHLORIDE  SULPHATE  \
# 0  7.90   552   865   452  272   180  0.2   4.5  260   44       375       681
# 1  7.52  1985  2256  1054  529   525  0.0  15.0  272   47       728       324
# 2  7.65  1865  2032   636  371   265  0.0   9.0  373   25       713       503
# 3  7.25  4855  7856  2050  795  1255  0.0  12.5  335  106        81       676
# 4  7.96  2855  3696   865  310   555  0.3   4.6  184  106       698       324
#
#    NITRATE  FLUORIDE  Pre monsoon EWQI
# 0       60      0.40              70.52
# 1       10      0.65             138.78
# 2       54      0.85             113.07
# 3       17      0.69             266.32
# 4       25      1.20             158.05
#
# Shape of test data: (47, 15)
# First 5 rows of test data:
#       pH   TDS    EC    TH     ca      mg  CO3  HCO3   NA    K  CHLORIDE  \
# 0  8.38   625   975   320  120.0   200.0  0.0   5.8  280   35       398
# 1  7.31  2020  2860   960  410.0   550.0  0.0  11.0  302   65       765
# 2  7.80  1630  2380   440  165.0   275.0  0.0   7.0  356   29       745
# 3  7.06  6300  8910  2356  776.0  1580.0  0.0  10.8  396  112       124
# 4  4.60  2290  3570  1080  470.0   610.0  0.0   6.2  225  125       745
#
#    SULPHATE  NITRATE  FLUORIDE  Post monsoon EWQI
# 0       755       75      0.48              73.07
# 1       365       26      0.71             141.67
# 2       525       85      0.89             110.44
# 3       745       24      0.75             275.01
# 4       336       15      1.35             202.57

# %%
X_train = train_data.iloc[:, :-1]
y_train = train_data.iloc[:, -1]
X_test = test_data.iloc[:, :-1]
y_test = test_data.iloc[:, -1]
x_test= X_test
print("\nShape of X_train:", X_train.shape)
print("Shape of y_train:", y_train.shape)
print("Shape of X_test:", X_test.shape)
print("Shape of y_test:", y_test.shape)
# Out:
# Shape of X_train: (47, 14)
# Shape of y_train: (47,)
# Shape of X_test: (47, 14)
# Shape of y_test: (47,)

# %%
# Apply z-score normalization
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Print the first five rows of the normalized data
print("\nFirst five rows of normalized X_train:")
print(X_train[:5])

print("\nFirst five rows of normalized X_test:")
print(X_test[:5])
# Out:
# First five rows of normalized X_train:
# [[ 0.3797749  -1.15230942 -0.94309903 -0.47923131 -0.09229732 -0.56852482
#   -0.03922784 -1.18768739 -0.02713192 -0.87884263 -0.2770724   1.15873613
#    1.41276153 -1.25316406]
#  [-0.78765707 -0.2953837  -0.52059702  0.45803078  1.31357822  0.10564733
#   -0.50015494  1.61405127  0.07159325 -0.77136925  1.29937074 -0.45273785
#   -1.61366471 -0.53733141]
#  [-0.38827245 -0.36714301 -0.58863473 -0.19275917  0.44926563 -0.40242444
#   -0.50015494  0.01305775  0.90253007 -1.55950739  1.23238307  0.35525611
#    1.04959038  0.03533472]
#  [-1.61714822  1.42085972  1.18034563  2.00871688  2.76868675  1.53215652
#   -0.50015494  0.94697063  0.58990037  1.34227396 -1.59003071  1.13616647
#   -1.18996504 -0.42279818]
#  [ 0.56410627  0.22487128 -0.08321177  0.16377408  0.11557533  0.16427099
#    0.19123571 -1.16100417 -0.6523913   1.34227396  1.1653954  -0.45273785
#   -0.70573684  1.03750043]]
#
# First five rows of normalized X_test:
# [[ 1.85442582 -1.10865585 -0.90968766 -0.68474392 -0.92378791 -0.52944238
#   -0.50015494 -0.84080546  0.13741003 -1.20126278 -0.17435797  1.49276715
#    2.3206894  -1.02409761]
#  [-1.43281685 -0.2744539  -0.33713821  0.31168088  0.66260861  0.15450038
#   -0.50015494  0.54672225  0.31840617 -0.12652895  1.46460699 -0.26766661
#   -0.64520832 -0.36553157]
#  [ 0.07255596 -0.50767165 -0.48293329 -0.49791427 -0.67762293 -0.38288322
#   -0.50015494 -0.52060676  0.76266941 -1.41620955  1.37529009  0.45456263
#    2.92597465  0.14986794]
#  [-2.2008642   2.28496138  1.50048734  2.48513249  2.66475042  2.16724622
#   -0.50015494  0.4933558   1.0917533   1.55722072 -1.39799939  1.44762783
#   -0.76626537 -0.25099834]
#  [-9.75845017 -0.11299546 -0.12148298  0.49851054  0.99082858  0.27174771
#   -0.50015494 -0.73407256 -0.31508032  2.02293872  1.37529009 -0.39857066
#   -1.31102209  1.46700003]]

# %%
# Define the model classes
model_classes = {
    'Random Forest': RandomForestRegressor,
    'Gradient Boosting': GradientBoostingRegressor,
    'XGBoost': XGBRegressor,
    'LightGBM': LGBMRegressor,
    'GPBoost': GPBoostRegressor,
    'CatBoost': CatBoostRegressor,
    'NGBoost': NGBRegressor
}

feature_names =['pH','TDS' , 'EC','TH' ,'ca', 'mg ',' CO3',  'HCO3', 'NA' ,'K ','CHLORIDE', 'SULPHATE', 'NITRATE','FLUORIDE' ]

# %%
def plot_best_scores(best_scores_ran, excel_file_path):
    # Extract the best pruner for each model based on RMSE and correlation coefficient
    best_rmse_scores = {}
    best_corr_coef_scores = {}

    for (model_name, pruner_name), scores in best_scores_ran.items():
        # Initialize if not already present
        if model_name not in best_rmse_scores:
            best_rmse_scores[model_name] = (scores['test_rmse'], pruner_name)
        if model_name not in best_corr_coef_scores:
            best_corr_coef_scores[model_name] = (scores['test_corr_coef'], pruner_name)

        # Update if better scores are found
        if scores['test_rmse'] < best_rmse_scores[model_name][0]:
            best_rmse_scores[model_name] = (scores['test_rmse'], pruner_name)
        if scores['test_corr_coef'] > best_corr_coef_scores[model_name][0]:
            best_corr_coef_scores[model_name] = (scores['test_corr_coef'], pruner_name)

    # Prepare data for plotting
    model_names_rmse = [f"{model} ({pruner})" for model, (rmse, pruner) in best_rmse_scores.items()]
    rmse_values = [rmse for rmse, _ in best_rmse_scores.values()]

    model_names_corr = [f"{model} ({pruner})" for model, (corr, pruner) in best_corr_coef_scores.items()]
    corr_values = [corr for corr, _ in best_corr_coef_scores.values()]

    # Plot RMSE
    plt.figure(figsize=(12, 6))
    bars_rmse = plt.bar(model_names_rmse, rmse_values, color='skyblue')

    # Highlight the best model
    best_rmse_index = np.argmin(rmse_values)
    bars_rmse[best_rmse_index].set_color('orange')

    # Annotate the bars with the RMSE scores
    for i, bar in enumerate(bars_rmse):
        plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() - 0.05,
                 f'{rmse_values[i]:.5f}', ha='center', va='bottom', color='black')

    # Add labels and title for the RMSE bar chart
    plt.xlabel('Model (Pruner)')
    plt.ylabel('Test RMSE')
    plt.title('Best Test RMSE for Each Model')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    rmse_image_path = 'rmse_plot.png'
    plt.savefig(rmse_image_path)
    plt.close()

    # Plot Correlation Coefficient
    plt.figure(figsize=(12, 6))
    bars_corr = plt.bar(model_names_corr, corr_values, color='lightgreen')

    # Highlight the best model
    best_corr_index = np.argmax(corr_values)
    bars_corr[best_corr_index].set_color('orange')

    # Annotate the bars with the correlation coefficient scores
    for i, bar in enumerate(bars_corr):
        plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() - 0.05,
                 f'{corr_values[i]:.5f}', ha='center', va='bottom', color='black')

    # Add labels and title for the correlation coefficient bar chart
    plt.xlabel('Model (Pruner)')
    plt.ylabel('Correlation Coefficient')
    plt.title('Best Correlation Coefficient for Each Model')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    corr_image_path = 'corr_plot.png'
    plt.savefig(corr_image_path)
    plt.close()

    # Load the existing Excel file
    # Optionally insert images and scores into an Excel file
    if excel_file_path:

      if not os.path.exists(excel_file_path):

        workbook = Workbook()  # Create a new workbook
        workbook.save(excel_file_path)  # Save it to the specified path
        print(f"Created a new Excel file at: {excel_file_path}")
      else:
        workbook = load_workbook(excel_file_path)  # Load existing workbook if it exists


    # Create a new sheet for the plots
    sheet_name = 'Best Models Plots'
    if sheet_name in workbook.sheetnames:
        sheet = workbook[sheet_name]
    else:
        sheet = workbook.create_sheet(title=sheet_name)

    # Insert images into the new Excel sheet
    img_rmse = Image(rmse_image_path)
    img_corr = Image(corr_image_path)

    # Insert images
    sheet.add_image(img_rmse, 'A1')
    sheet.add_image(img_corr, 'A20')  # Adjust the position as needed

    # Save the workbook
    workbook.save(excel_file_path)

    # Clean up the image files
    os.remove(rmse_image_path)
    os.remove(corr_image_path)

# Example usage
# plot_best_scores(best_scores_ran, 'path_to_your_excel_file.xlsx')

# %%
def generate_interpretml_explanations_summary_pruners(
    results_dict, X_train, y_train, X_test, feature_names, instance_indices=None, excel_file_path=None
):
    if instance_indices is None:
        instance_indices = range(len(X_test))
    elif isinstance(instance_indices, int):
        instance_indices = [instance_indices]

    valid_indices = [idx for idx in instance_indices if 0 <= idx < len(X_test)]
    if not valid_indices:
        print("No valid instance indices provided.")
        return

    if isinstance(X_test, pd.DataFrame):
        instances_to_explain = X_test.iloc[valid_indices]
    else:
        instances_to_explain = X_test[valid_indices]

    best_model_pruners = {}
    for model_key, model_info in results_dict.items():
        if isinstance(model_key, tuple):
            model_name, pruner_name = model_key
        else:
            model_name = model_key
            pruner_name = None

        best_score = model_info.get('best_score')
        if best_score is None:
            print(f"No 'best_score' found for {model_key}. Skipping this combination.")
            continue

        if model_name not in best_model_pruners:
            best_model_pruners[model_name] = {
                'pruner_name': pruner_name,
                'model_info': model_info,
                'best_score': best_score
            }
        else:
            current_best_score = best_model_pruners[model_name]['best_score']
            if best_score < current_best_score:
                best_model_pruners[model_name] = {
                    'pruner_name': pruner_name,
                    'model_info': model_info,
                    'best_score': best_score
                }

    for model_name, info in best_model_pruners.items():
        pruner_name = info['pruner_name']
        model_info = info['model_info']
        best_params = model_info['best_params']
        model_class = model_classes.get(model_name)

        if model_class is None:
            print(f"Model {model_name} is not supported or not available.")
            continue

        if model_name == 'CatBoost':
            best_params['verbose'] = 0

        model = model_class(**best_params)
        model.fit(X_train, y_train)

        def predict_fn(data):
            return model.predict(data)

        if isinstance(X_train, pd.DataFrame):
            data_for_explainer = X_train.values
        else:
            data_for_explainer = X_train

        if isinstance(instances_to_explain, pd.DataFrame):
            data_for_explanation = instances_to_explain.values
        else:
            data_for_explanation = instances_to_explain

        # Generate LIME explanations
        lime_explainer = LimeTabular(
            predict_fn,
            data=data_for_explainer,
            feature_names=feature_names,
            random_state=1,
            mode='regression'
        )
        lime_explanation = lime_explainer.explain_local(data_for_explanation)

        feature_importances_lime = {}
        num_instances = len(valid_indices)

        for idx in range(num_instances):
            explanation = lime_explanation.data(idx)
            for feature_name, feature_score in zip(explanation['names'], explanation['scores']):
                feature_importances_lime[feature_name] = feature_importances_lime.get(feature_name, 0) + abs(feature_score)

        feature_importances_lime = {k: v / num_instances for k, v in feature_importances_lime.items()}
        feature_importances_lime = {k: round(v, 3) for k, v in feature_importances_lime.items()}

        # Generate SHAP explanations using ShapKernel
        try:
            shap_explainer = ShapKernel(predict_fn, data_for_explainer, feature_names=feature_names)
            shap_explanation = shap_explainer.explain_local(data_for_explanation)

            feature_importances_shap = {}
            for idx in range(num_instances):
                explanation = shap_explanation.data(idx)
                for feature_name, feature_score in zip(explanation['names'], explanation['scores']):
                    feature_importances_shap[feature_name] = feature_importances_shap.get(feature_name, 0) + abs(feature_score)

            feature_importances_shap = {k: v / num_instances for k, v in feature_importances_shap.items()}
            feature_importances_shap = {k: round(v, 3) for k, v in feature_importances_shap.items()}
        except Exception as e:
            print(f"Could not compute SHAP values for model {model_name}: {e}")
            continue

        # Plot LIME and SHAP feature importances side by side
        fig, axes = plt.subplots(1, 2, figsize=(34, 36))

        # Plot LIME feature importances
        lime_importances_df = pd.DataFrame.from_dict(
            feature_importances_lime, orient='index', columns=['importance']
        )
        lime_importances_df.sort_values(by='importance', ascending=False, inplace=True)
        lime_importances_df.plot(kind='bar', legend=False, color='skyblue', ax=axes[0])
        axes[0].set_title(f"LIME Feature Importances for {model_name}")
        axes[0].set_ylabel("Average Absolute Importance Score")
        axes[0].set_xlabel("Features")
        axes[0].tick_params(axis='x', rotation=45)

        for p in axes[0].patches:
            height = p.get_height()
            axes[0].annotate(f'{height:.3f}',
                             (p.get_x() + p.get_width() / 2., height),
                             ha='center', va='bottom', fontsize=8)

        # Plot SHAP feature importances
        shap_importances_df = pd.DataFrame.from_dict(
            feature_importances_shap, orient='index', columns=['importance']
        )
        shap_importances_df.sort_values(by='importance', ascending=False, inplace=True)
        shap_importances_df.plot(kind='bar', legend=False, color='orange', ax=axes[1])
        axes[1].set_title(f"SHAP Feature Importances for {model_name}")
        axes[1].set_ylabel("Average Absolute SHAP Value")
        axes[1].set_xlabel("Features")
        axes[1].tick_params(axis='x', rotation=45)

        for p in axes[1].patches:
            height = p.get_height()
            axes[1].annotate(f'{height:.3f}',
                             (p.get_x() + p.get_width() / 2., height),
                             ha='center', va='bottom', fontsize=8)

        plt.tight_layout()

        # Save plots as images
        image_path = f'feature_importances_{model_name}.png'
        fig.savefig(image_path)
        plt.close(fig)

        # Optionally insert images and scores into an Excel file
        if excel_file_path:
            if not os.path.exists(excel_file_path):
              workbook = Workbook()  # Create a new workbook
              workbook.save(excel_file_path)  # Save it to the specified path
              print(f"Created a new Excel file at: {excel_file_path}")
            else:
              workbook = load_workbook(excel_file_path)  # Load existing workbook if it exists


            sheet_name = f'{model_name} Explanations'
            if sheet_name in workbook.sheetnames:
                sheet = workbook[sheet_name]
            else:
                sheet = workbook.create_sheet(title=sheet_name)

            # Insert images into the new Excel sheet
            img = Image(image_path)
            sheet.add_image(img, 'A1')

            # Create a new sheet for feature importance scores
            scores_sheet_name = f'{model_name} Scores'
            if scores_sheet_name in workbook.sheetnames:
                scores_sheet = workbook[scores_sheet_name]
            else:
                scores_sheet = workbook.create_sheet(title=scores_sheet_name)

            # Write LIME scores
            scores_sheet.append(['Feature', 'LIME Importance'])
            for feature, importance in feature_importances_lime.items():
                scores_sheet.append([feature, importance])

            # Write SHAP scores
            scores_sheet.append(['Feature', 'SHAP Importance'])
            for feature, importance in feature_importances_shap.items():
                scores_sheet.append([feature, importance])

            # Save the workbook
            workbook.save(excel_file_path)

            # Clean up the image file
            os.remove(image_path)

# %% [markdown]
# # **Autosampler by Optuna**

# %%
# Suppress Optuna's verbose output
optuna.logging.set_verbosity(optuna.logging.WARNING)

# Define objective and metric functions for PGBM
def mseloss_objective(yhat, y, sample_weight=None):
    if not torch.is_tensor(yhat):
        yhat = torch.from_numpy(np.array(yhat)).float()
    if not torch.is_tensor(y):
        y = torch.from_numpy(np.array(y)).float()
    gradient = yhat - y
    hessian = torch.ones_like(yhat)
    return gradient, hessian

def rmseloss_metric(yhat, y, sample_weight=None):
    if not torch.is_tensor(yhat):
        yhat = torch.from_numpy(np.array(yhat)).float()
    if not torch.is_tensor(y):
        y = torch.from_numpy(np.array(y)).float()
    loss = torch.sqrt(torch.mean((yhat - y) ** 2))
    return loss

def hyperparameter_tuning_all(X_train, y_train, X_test, y_test, excel_path):
    X_train = np.array(X_train)
    y_train = np.array(y_train)
    X_test = np.array(X_test)
    y_test = np.array(y_test)

    models = {
        'Random Forest': (RandomForestRegressor, {
            'n_estimators': [100, 200, 300, 500, 700],
            'criterion': ['squared_error', 'absolute_error', 'friedman_mse', 'poisson'],
            'max_depth': [None, 10, 20, 30, 40],
            'min_samples_split': [2, 5, 10, 0.01],
            'min_samples_leaf': [1, 3, 5, 0.01],
            'min_weight_fraction_leaf': [0.0, 0.01, 0.1, 0.2],
            'max_features': [1.0, 'sqrt', 'log2', 0.3, 0.5],
            'max_leaf_nodes': [None, 50, 100, 200],
            'min_impurity_decrease': [0.0, 0.01, 0.1, 0.2],
            'n_jobs': [-1],
            'random_state': [42],
            'verbose': [0],
            'warm_start': [False],
            'ccp_alpha': [0.0, 0.001, 0.01, 0.05, 0.1]
        }),
        'Gradient Boosting': (GradientBoostingRegressor, {
            'loss': ['squared_error', 'absolute_error', 'huber', 'quantile'],
            'learning_rate': [0.01, 0.05, 0.1, 0.2],
            'n_estimators': [100, 200, 300, 500, 700],
            'subsample': [1.0, 0.9, 0.7, 0.5],
            'criterion': ['friedman_mse', 'squared_error'],
            'min_samples_split': [2, 5, 10, 0.01],
            'min_samples_leaf': [1, 3, 5, 0.01],
            'min_weight_fraction_leaf': [0.0, 0.01, 0.05, 0.1],
            'max_depth': [3, 5, 7, 10],
            'min_impurity_decrease': [0.0, 0.01, 0.1],
            'init': [None],
            'random_state': [42],
            'max_features': [None, 'sqrt', 'log2', 0.5],
            'alpha': [0.9, 0.5, 0.1],
            'verbose': [0],
            'max_leaf_nodes': [None, 10, 30, 50],
            'warm_start': [False],
            'validation_fraction': [0.1],
            'n_iter_no_change': [None, 10, 20],
            'tol': [1e-4, 1e-3],
            'ccp_alpha': [0.0, 0.001, 0.01]
        }),
        'XGBoost': (XGBRegressor, {
            'n_estimators': [100, 200, 300, 400, 500],
            'learning_rate': [0.01, 0.05, 0.1, 0.15],
            'max_depth': [3, 5, 7],
            'min_child_weight': [1, 3, 5],
            'gamma': [0, 0.1, 0.5, 1],
            'subsample': [0.5, 0.6, 0.7, 0.8, 0.9],
            'colsample_bytree': [0.5, 0.7, 0.9],
            'colsample_bylevel': [0.5, 0.7, 0.9],
            'reg_alpha': [0, 0.01, 0.1, 1],
            'reg_lambda': [0.1, 1, 5, 10],
            'objective': ['reg:squarederror'],
            'random_state': [42],
            'n_jobs': [-1]
        }),
        'LightGBM': (LGBMRegressor, {
            'n_estimators': [100, 200, 300, 400, 500],
            'learning_rate': [0.01, 0.05, 0.1, 0.15],
            'num_leaves': [15, 31, 63],
            'max_depth': [3, 5, 7, -1],
            'min_child_samples': [1, 5, 10, 20],
            'subsample': [0.5, 0.6, 0.7, 0.8, 0.9, 1.0],
            'colsample_bytree': [0.5, 0.7, 0.9, 1.0],
            'reg_alpha': [0, 0.01, 0.1, 1],
            'reg_lambda': [0, 0.1, 1, 10],
            'min_child_weight': [1e-5, 1e-3, 1e-2, 1e-1],
            'bagging_freq': [0, 1, 5],
            'objective': ['regression'],
            'random_state': [42],
            'n_jobs': [-1],
            'verbose': [-1]
        }),
        'GPBoost': (GPBoostRegressor, {
            'n_estimators': [100, 200, 300, 400, 500],
            'learning_rate': [0.01, 0.05, 0.1, 0.15],
            'max_depth': [3, 5, 7, -1],
            'num_leaves': [15, 31, 63],
            'min_child_samples': [1, 5, 10, 20],
            'subsample': [0.5, 0.6, 0.7, 0.8, 0.9, 1.0],
            'colsample_bytree': [0.5, 0.7, 0.9, 1.0],
            'reg_alpha': [0, 0.1, 0.5, 1.0],
            'reg_lambda': [0, 0.1, 0.5, 1.0],
            'min_child_weight': [1e-5, 1e-3, 1e-2, 1e-1],
            'random_state': [42],
            'n_jobs': [-1],
            'verbose': [-1]
        }),
        'CatBoost': (CatBoostRegressor, {
            'iterations': [200, 500, 1000],
            'learning_rate': [0.01, 0.03, 0.05, 0.1],
            'depth': [4, 6, 8, 10],
            'l2_leaf_reg': [1, 3, 5, 7, 9],
            'border_count': [32, 64, 128],
            'min_data_in_leaf': [1, 5, 10, 20],
            'rsm': [0.6, 0.8, 1.0],
            'bagging_temperature': [0, 1, 10],
            'random_seed': [42],
            'verbose': [0]
        }),
        'NGBoost': (NGBRegressor, {
            'n_estimators': [200, 500, 1000],
            'learning_rate': [0.01, 0.03, 0.05, 0.1],
            'natural_gradient': [True, False],
            'minibatch_frac': [0.5, 0.7, 0.9, 1.0],
            'col_sample': [0.5, 0.7, 0.9, 1.0],
            'Dist': [Normal],
            'Score': [LogScore],
            'random_state': [42],
            'verbose': [0]
        }),
        'HistGradientBoosting': (HistGradientBoostingRegressor, {
            'learning_rate': [0.01, 0.05, 0.1, 0.15],
            'max_iter': [100, 200, 300, 400, 500],
            'max_depth': [3, 5, 7, None],
            'min_samples_leaf': [5, 10, 20],
            'max_leaf_nodes': [15, 31, 63, None],
            'l2_regularization': [0.0, 0.1, 0.5, 1.0],
            'max_bins': [64, 128, 255],
            'early_stopping': [True, False],
            'validation_fraction': [0.1, 0.2],
            'n_iter_no_change': [5, 10, 15],
            'loss': ['squared_error'],
            'random_state': [42],
            'verbose': [0]
        }),
        'PGBM': (PGBM, {}) # PGBM is handled separately
    }


    pruners = [
        optuna.pruners.MedianPruner(),
        optuna.pruners.NopPruner(),
        optuna.pruners.PatientPruner(optuna.pruners.MedianPruner(), patience=3),
        optuna.pruners.PercentilePruner(25.0),
        optuna.pruners.SuccessiveHalvingPruner(),
        optuna.pruners.HyperbandPruner(),
        optuna.pruners.ThresholdPruner(lower=0.1),
        optuna.pruners.WilcoxonPruner()
    ]

    best_scores = {}
    predictions_df = pd.DataFrame({'Actual': y_test})

    for model_name, (model_class, param_space) in models.items():
        for pruner in pruners:
            pruner_name = pruner.__class__.__name__
            print(f"Running Optuna for {model_name} with {pruner_name}...")
            try:
                sampler = optunahub.load_module("samplers/auto_sampler").AutoSampler()
                study = optuna.create_study(direction='minimize', sampler=sampler, pruner=pruner)

                if model_name == 'PGBM':
                    def pgbm_objective(trial):
                        params = {
                            'n_estimators': trial.suggest_categorical('n_estimators', [100, 200, 300, 500]),
                            'learning_rate': trial.suggest_categorical('learning_rate', [0.01, 0.05, 0.1, 0.15]),
                            'max_leaves': trial.suggest_int('max_leaves', 15, 63),
                            'min_split_gain': trial.suggest_categorical('min_split_gain', [0.0, 0.1, 0.5, 1.0]),
                            'reg_lambda': trial.suggest_categorical('reg_lambda', [0.1, 1.0, 5.0, 10.0]),
                            'feature_fraction': trial.suggest_categorical('feature_fraction', [0.5, 0.7, 0.9, 1.0]),
                            'bagging_fraction': trial.suggest_categorical('bagging_fraction', [0.5, 0.7, 0.9, 1.0]),
                            'tree_correlation': trial.suggest_categorical('tree_correlation', [0.0, 0.1, 0.2, 0.3]),
                            'min_data_in_leaf': trial.suggest_categorical('min_data_in_leaf', [3, 5, 10, 20]),
                            'max_bin': trial.suggest_categorical('max_bin', [64, 128, 256]),
                            'distribution': trial.suggest_categorical('distribution', ['normal', 'studentt', 'laplace']),
                            'objective': 'mse',
                            'metric': 'rmse',
                            'random_state': 42,
                            'verbose': 0
                        }

                        model = PGBM()
                        model.train((X_train, y_train), objective=mseloss_objective, metric=rmseloss_metric, params=params)
                        y_pred = model.predict(X_test)
                        mse = mean_squared_error(y_test, y_pred)
                        return mse

                    study.optimize(pgbm_objective, n_trials=1)
                else:
                    def objective(trial, model_name, model_class, param_space):
                        params = {}
                        for key, values in param_space.items():
                            if isinstance(values, list):
                                params[key] = trial.suggest_categorical(key, values)
                            elif isinstance(values, tuple):
                                if len(values) == 2:
                                    params[key] = trial.suggest_float(key, values[0], values[1])
                                elif len(values) == 3 and isinstance(values[2], bool) and values[2]:
                                    params[key] = trial.suggest_int(key, values[0], values[1])
                                else:
                                    raise ValueError(f"Invalid parameter range for {key}")

                        model = model_class(**params)
                        model.fit(X_train, y_train)
                        y_pred = model.predict(X_test)
                        mse = mean_squared_error(y_test, y_pred)
                        return mse

                    study.optimize(lambda trial: objective(trial, model_name, model_class, param_space), n_trials=50)

                best_params = study.best_params
                best_model = model_class(**best_params) if model_name != 'PGBM' else PGBM()
                if model_name == 'PGBM':
                    best_model.train((X_train, y_train), objective=mseloss_objective, metric=rmseloss_metric, params=best_params)
                else:
                    best_model.fit(X_train, y_train)
                y_pred = best_model.predict(X_test)

                mse = mean_squared_error(y_test, y_pred)
                rmse = np.sqrt(mse)
                corr_coef = np.corrcoef(y_test, y_pred)[0, 1]

                # Save predictions to DataFrame
                predictions_df[f'{model_name}_{pruner_name}_Predicted'] = y_pred

                best_scores[(model_name, pruner_name)] = {
                    'best_score': mse,
                    'best_params': best_params,
                    'test_mse': mse,
                    'test_rmse': rmse,
                    'test_corr_coef': corr_coef,
                    'pruner': pruner_name
                }
                print(f"Best MSE for {model_name} with {pruner_name}: {mse} with params: {best_params}")
                print(f"Best RMSE for {model_name} with {pruner_name}: {rmse}")
                print(f"Correlation Coefficient for {model_name} with {pruner_name}: {corr_coef}")
            except Exception as e:
                print(f"Failed to run Optuna for {model_name} with {pruner_name}. Error: {e}")

    # Write predictions to Excel
    import os
    excel_path = "./drive/MyDrive/water_analysis/test.xlsx"
    if not os.path.exists(excel_path):

    # Create a new Excel file
      workbook = Workbook()
      workbook.save(excel_path)
      print(f"Created a new Excel file at: {excel_path}")
    with pd.ExcelWriter(excel_path, engine='openpyxl', mode='a') as writer:
        predictions_df.to_excel(writer, sheet_name='Predictions', index=False)

    if best_scores:
        best_model_name, best_pruner_name = min(best_scores, key=lambda k: best_scores[k]['test_mse'])
        best_model_info = best_scores[(best_model_name, best_pruner_name)]
        print(f"\nBest model on test data: {best_model_name} with {best_pruner_name}")
        print(f"Test MSE: {best_model_info['test_mse']}")
        print(f"Test RMSE: {best_model_info['test_rmse']}")
        print(f"Correlation Coefficient: {best_model_info['test_corr_coef']}")
        print(f"Best Parameters: {best_model_info['best_params']}")
        print(f"Pruner Used: {best_model_info['pruner']}")
    else:
        print("No valid model configurations found.")

    return best_scores


best_scores_autosampler = hyperparameter_tuning_all(X_train, y_train, X_test, y_test, "./drive/MyDrive/water_analysis/test.xlsx")
# Out:
# Running Optuna for Random Forest with MedianPruner...
# Best MSE for Random Forest with MedianPruner: 494.0832274465908 with params: {'n_estimators': 100, 'criterion': 'squared_error', 'max_depth': 40, 'min_samples_split': 0.01, 'min_samples_leaf': 0.01, 'min_weight_fraction_leaf': 0.01, 'max_features': 1.0, 'max_leaf_nodes': 200, 'min_impurity_decrease': 0.0, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.1}
# Best RMSE for Random Forest with MedianPruner: 22.227982981966466
# Correlation Coefficient for Random Forest with MedianPruner: 0.9562504266776625
# Running Optuna for Random Forest with NopPruner...
# Best MSE for Random Forest with NopPruner: 498.42412699059673 with params: {'n_estimators': 700, 'criterion': 'squared_error', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.0, 'max_features': 0.5, 'max_leaf_nodes': 50, 'min_impurity_decrease': 0.01, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.0}
# Best RMSE for Random Forest with NopPruner: 22.325414374443238
# Correlation Coefficient for Random Forest with NopPruner: 0.9565152609582364
# Running Optuna for Random Forest with PatientPruner...
# Best MSE for Random Forest with PatientPruner: 501.77203003955043 with params: {'n_estimators': 300, 'criterion': 'squared_error', 'max_depth': 10, 'min_samples_split': 0.01, 'min_samples_leaf': 0.01, 'min_weight_fraction_leaf': 0.01, 'max_features': 1.0, 'max_leaf_nodes': 200, 'min_impurity_decrease': 0.01, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.001}
# Best RMSE for Random Forest with PatientPruner: 22.400268526059023
# Correlation Coefficient for Random Forest with PatientPruner: 0.9577060428217671
# Running Optuna for Random Forest with PercentilePruner...
# Best MSE for Random Forest with PercentilePruner: 502.5656396305721 with params: {'n_estimators': 300, 'criterion': 'absolute_error', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.0, 'max_features': 0.5, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.01, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.001}
# Best RMSE for Random Forest with PercentilePruner: 22.417975814746793
# Correlation Coefficient for Random Forest with PercentilePruner: 0.9544318450063605
# Running Optuna for Random Forest with SuccessiveHalvingPruner...
# Best MSE for Random Forest with SuccessiveHalvingPruner: 499.70003183856176 with params: {'n_estimators': 200, 'criterion': 'friedman_mse', 'max_depth': 30, 'min_samples_split': 2, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.01, 'max_features': 1.0, 'max_leaf_nodes': 50, 'min_impurity_decrease': 0.0, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.01}
# Best RMSE for Random Forest with SuccessiveHalvingPruner: 22.353971276678372
# Correlation Coefficient for Random Forest with SuccessiveHalvingPruner: 0.9555634577545703
# Running Optuna for Random Forest with HyperbandPruner...
# Best MSE for Random Forest with HyperbandPruner: 506.9664016421923 with params: {'n_estimators': 300, 'criterion': 'friedman_mse', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.0, 'max_features': 1.0, 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.1, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.001}
# Best RMSE for Random Forest with HyperbandPruner: 22.515914408306678
# Correlation Coefficient for Random Forest with HyperbandPruner: 0.9565188484300761
# Running Optuna for Random Forest with ThresholdPruner...
# Best MSE for Random Forest with ThresholdPruner: 499.0133409866187 with params: {'n_estimators': 200, 'criterion': 'absolute_error', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 0.01, 'min_weight_fraction_leaf': 0.01, 'max_features': 1.0, 'max_leaf_nodes': 100, 'min_impurity_decrease': 0.2, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.05}
# Best RMSE for Random Forest with ThresholdPruner: 22.33860651398423
# Correlation Coefficient for Random Forest with ThresholdPruner: 0.9581329488959802
# Running Optuna for Random Forest with WilcoxonPruner...
# Best MSE for Random Forest with WilcoxonPruner: 499.03317084662626 with params: {'n_estimators': 700, 'criterion': 'squared_error', 'max_depth': 40, 'min_samples_split': 2, 'min_samples_leaf': 0.01, 'min_weight_fraction_leaf': 0.01, 'max_features': 0.5, 'max_leaf_nodes': 200, 'min_impurity_decrease': 0.2, 'n_jobs': -1, 'random_state': 42, 'verbose': 0, 'warm_start': False, 'ccp_alpha': 0.0}
# Best RMSE for Random Forest with WilcoxonPruner: 22.3390503568667
# Correlation Coefficient for Random Forest with WilcoxonPruner: 0.9564495763116471
# Running Optuna for Gradient Boosting with MedianPruner...
# Best MSE for Gradient Boosting with MedianPruner: 191.0133084285086 with params: {'loss': 'squared_error', 'learning_rate': 0.05, 'n_estimators': 200, 'subsample': 0.5, 'criterion': 'squared_error', 'min_samples_split': 2, 'min_samples_leaf': 0.01, 'min_weight_fraction_leaf': 0.01, 'max_depth': 3, 'min_impurity_decrease': 0.0, 'init': None, 'random_state': 42, 'max_features': None, 'alpha': 0.9, 'verbose': 0, 'max_leaf_nodes': None, 'warm_start': False, 'validation_fraction': 0.1, 'n_iter_no_change': 20, 'tol': 0.0001, 'ccp_alpha': 0.0}
# Best RMSE for Gradient Boosting with MedianPruner: 13.820756434743672
# Correlation Coefficient for Gradient Boosting with MedianPruner: 0.9745455081893564
# Running Optuna for Gradient Boosting with NopPruner...
# Best MSE for Gradient Boosting with NopPruner: 176.67485993940775 with params: {'loss': 'squared_error', 'learning_rate': 0.05, 'n_estimators': 300, 'subsample': 0.7, 'criterion': 'friedman_mse', 'min_samples_split': 5, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.0, 'max_depth': 5, 'min_impurity_decrease': 0.01, 'init': None, 'random_state': 42, 'max_features': None, 'alpha': 0.1, 'verbose': 0, 'max_leaf_nodes': 30, 'warm_start': False, 'validation_fraction': 0.1, 'n_iter_no_change': 10, 'tol': 0.0001, 'ccp_alpha': 0.0}
# Best RMSE for Gradient Boosting with NopPruner: 13.291909567079056
# Correlation Coefficient for Gradient Boosting with NopPruner: 0.9780654642635519
# Running Optuna for Gradient Boosting with PatientPruner...
# Best MSE for Gradient Boosting with PatientPruner: 155.26382478955753 with params: {'loss': 'squared_error', 'learning_rate': 0.05, 'n_estimators': 500, 'subsample': 0.7, 'criterion': 'friedman_mse', 'min_samples_split': 10, 'min_samples_leaf': 0.01, 'min_weight_fraction_leaf': 0.0, 'max_depth': 5, 'min_impurity_decrease': 0.1, 'init': None, 'random_state': 42, 'max_features': 0.5, 'alpha': 0.1, 'verbose': 0, 'max_leaf_nodes': 10, 'warm_start': False, 'validation_fraction': 0.1, 'n_iter_no_change': None, 'tol': 0.0001, 'ccp_alpha': 0.0}
# Best RMSE for Gradient Boosting with PatientPruner: 12.460490551722172
# Correlation Coefficient for Gradient Boosting with PatientPruner: 0.9800953042627318
# Running Optuna for Gradient Boosting with PercentilePruner...
# Best MSE for Gradient Boosting with PercentilePruner: 169.34283962923186 with params: {'loss': 'squared_error', 'learning_rate': 0.05, 'n_estimators': 100, 'subsample': 0.7, 'criterion': 'squared_error', 'min_samples_split': 10, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.01, 'max_depth': 3, 'min_impurity_decrease': 0.1, 'init': None, 'random_state': 42, 'max_features': None, 'alpha': 0.5, 'verbose': 0, 'max_leaf_nodes': 50, 'warm_start': False, 'validation_fraction': 0.1, 'n_iter_no_change': 10, 'tol': 0.0001, 'ccp_alpha': 0.0}
# Best RMSE for Gradient Boosting with PercentilePruner: 13.01317945888828
# Correlation Coefficient for Gradient Boosting with PercentilePruner: 0.9761672902842062
# Running Optuna for Gradient Boosting with SuccessiveHalvingPruner...
# Best MSE for Gradient Boosting with SuccessiveHalvingPruner: 177.32280622709055 with params: {'loss': 'squared_error', 'learning_rate': 0.05, 'n_estimators': 700, 'subsample': 0.7, 'criterion': 'friedman_mse', 'min_samples_split': 10, 'min_samples_leaf': 0.01, 'min_weight_fraction_leaf': 0.0, 'max_depth': 7, 'min_impurity_decrease': 0.1, 'init': None, 'random_state': 42, 'max_features': 0.5, 'alpha': 0.9, 'verbose': 0, 'max_leaf_nodes': 30, 'warm_start': False, 'validation_fraction': 0.1, 'n_iter_no_change': None, 'tol': 0.0001, 'ccp_alpha': 0.01}
# Best RMSE for Gradient Boosting with SuccessiveHalvingPruner: 13.316260970223231
# Correlation Coefficient for Gradient Boosting with SuccessiveHalvingPruner: 0.9787399487142573
# Running Optuna for Gradient Boosting with HyperbandPruner...
# Best MSE for Gradient Boosting with HyperbandPruner: 161.03029266801352 with params: {'loss': 'squared_error', 'learning_rate': 0.05, 'n_estimators': 300, 'subsample': 0.5, 'criterion': 'friedman_mse', 'min_samples_split': 10, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.05, 'max_depth': 3, 'min_impurity_decrease': 0.0, 'init': None, 'random_state': 42, 'max_features': None, 'alpha': 0.9, 'verbose': 0, 'max_leaf_nodes': 30, 'warm_start': False, 'validation_fraction': 0.1, 'n_iter_no_change': None, 'tol': 0.0001, 'ccp_alpha': 0.001}
# Best RMSE for Gradient Boosting with HyperbandPruner: 12.689771182649967
# Correlation Coefficient for Gradient Boosting with HyperbandPruner: 0.9762767640815191
# Running Optuna for Gradient Boosting with ThresholdPruner...
# Best MSE for Gradient Boosting with ThresholdPruner: 173.41940240454602 with params: {'loss': 'squared_error', 'learning_rate': 0.2, 'n_estimators': 100, 'subsample': 0.9, 'criterion': 'friedman_mse', 'min_samples_split': 5, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.05, 'max_depth': 3, 'min_impurity_decrease': 0.0, 'init': None, 'random_state': 42, 'max_features': None, 'alpha': 0.9, 'verbose': 0, 'max_leaf_nodes': 10, 'warm_start': False, 'validation_fraction': 0.1, 'n_iter_no_change': None, 'tol': 0.0001, 'ccp_alpha': 0.0}
# Best RMSE for Gradient Boosting with ThresholdPruner: 13.16888007404373
# Correlation Coefficient for Gradient Boosting with ThresholdPruner: 0.979515687794808
# Running Optuna for Gradient Boosting with WilcoxonPruner...
# Best MSE for Gradient Boosting with WilcoxonPruner: 145.8174616849565 with params: {'loss': 'squared_error', 'learning_rate': 0.05, 'n_estimators': 300, 'subsample': 0.7, 'criterion': 'friedman_mse', 'min_samples_split': 10, 'min_samples_leaf': 0.01, 'min_weight_fraction_leaf': 0.01, 'max_depth': 7, 'min_impurity_decrease': 0.0, 'init': None, 'random_state': 42, 'max_features': None, 'alpha': 0.5, 'verbose': 0, 'max_leaf_nodes': None, 'warm_start': False, 'validation_fraction': 0.1, 'n_iter_no_change': None, 'tol': 0.001, 'ccp_alpha': 0.0}
# Best RMSE for Gradient Boosting with WilcoxonPruner: 12.075490121935278
# Correlation Coefficient for Gradient Boosting with WilcoxonPruner: 0.9799339191310297
# Running Optuna for XGBoost with MedianPruner...
# Best MSE for XGBoost with MedianPruner: 167.48354105000854 with params: {'n_estimators': 400, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 3, 'gamma': 0, 'subsample': 0.6, 'colsample_bytree': 0.9, 'colsample_bylevel': 0.5, 'reg_alpha': 0.01, 'reg_lambda': 0.1, 'objective': 'reg:squarederror', 'random_state': 42, 'n_jobs': -1}
# Best RMSE for XGBoost with MedianPruner: 12.941543225211147
# Correlation Coefficient for XGBoost with MedianPruner: 0.9773359945592573
# Running Optuna for XGBoost with NopPruner...
# Best MSE for XGBoost with NopPruner: 236.71268109376012 with params: {'n_estimators': 300, 'learning_rate': 0.15, 'max_depth': 5, 'min_child_weight': 3, 'gamma': 0, 'subsample': 0.7, 'colsample_bytree': 0.9, 'colsample_bylevel': 0.9, 'reg_alpha': 0, 'reg_lambda': 0.1, 'objective': 'reg:squarederror', 'random_state': 42, 'n_jobs': -1}
# Best RMSE for XGBoost with NopPruner: 15.385469804128833
# Correlation Coefficient for XGBoost with NopPruner: 0.9659065395777474
# Running Optuna for XGBoost with PatientPruner...
# Best MSE for XGBoost with PatientPruner: 208.80286778526713 with params: {'n_estimators': 500, 'learning_rate': 0.05, 'max_depth': 3, 'min_child_weight': 1, 'gamma': 1, 'subsample': 0.7, 'colsample_bytree': 0.9, 'colsample_bylevel': 0.7, 'reg_alpha': 1, 'reg_lambda': 1, 'objective': 'reg:squarederror', 'random_state': 42, 'n_jobs': -1}
# Best RMSE for XGBoost with PatientPruner: 14.450012726128207
# Correlation Coefficient for XGBoost with PatientPruner: 0.976663363418376
# Running Optuna for XGBoost with PercentilePruner...
# Best MSE for XGBoost with PercentilePruner: 222.43444086923606 with params: {'n_estimators': 200, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 3, 'gamma': 0, 'subsample': 0.9, 'colsample_bytree': 0.9, 'colsample_bylevel': 0.5, 'reg_alpha': 1, 'reg_lambda': 1, 'objective': 'reg:squarederror', 'random_state': 42, 'n_jobs': -1}
# Best RMSE for XGBoost with PercentilePruner: 14.914236181220815
# Correlation Coefficient for XGBoost with PercentilePruner: 0.9720838341949776
# Running Optuna for XGBoost with SuccessiveHalvingPruner...
# Best MSE for XGBoost with SuccessiveHalvingPruner: 198.17237294214013 with params: {'n_estimators': 500, 'learning_rate': 0.15, 'max_depth': 5, 'min_child_weight': 3, 'gamma': 1, 'subsample': 0.7, 'colsample_bytree': 0.9, 'colsample_bylevel': 0.7, 'reg_alpha': 0, 'reg_lambda': 0.1, 'objective': 'reg:squarederror', 'random_state': 42, 'n_jobs': -1}
# Best RMSE for XGBoost with SuccessiveHalvingPruner: 14.077370952778795
# Correlation Coefficient for XGBoost with SuccessiveHalvingPruner: 0.9709271450848449
# Running Optuna for XGBoost with HyperbandPruner...
# Best MSE for XGBoost with HyperbandPruner: 199.9752973212219 with params: {'n_estimators': 300, 'learning_rate': 0.15, 'max_depth': 3, 'min_child_weight': 1, 'gamma': 0, 'subsample': 0.6, 'colsample_bytree': 0.9, 'colsample_bylevel': 0.7, 'reg_alpha': 0, 'reg_lambda': 0.1, 'objective': 'reg:squarederror', 'random_state': 42, 'n_jobs': -1}
# Best RMSE for XGBoost with HyperbandPruner: 14.141262225177138
# Correlation Coefficient for XGBoost with HyperbandPruner: 0.9727053213725442
# Running Optuna for XGBoost with ThresholdPruner...
# Best MSE for XGBoost with ThresholdPruner: 212.36630646483607 with params: {'n_estimators': 500, 'learning_rate': 0.05, 'max_depth': 3, 'min_child_weight': 1, 'gamma': 0.5, 'subsample': 0.5, 'colsample_bytree': 0.9, 'colsample_bylevel': 0.5, 'reg_alpha': 0, 'reg_lambda': 1, 'objective': 'reg:squarederror', 'random_state': 42, 'n_jobs': -1}
# Best RMSE for XGBoost with ThresholdPruner: 14.57279336520065
# Correlation Coefficient for XGBoost with ThresholdPruner: 0.9709231163297497
# Running Optuna for XGBoost with WilcoxonPruner...
# Best MSE for XGBoost with WilcoxonPruner: 181.91058581839525 with params: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 1, 'gamma': 1, 'subsample': 0.6, 'colsample_bytree': 0.7, 'colsample_bylevel': 0.9, 'reg_alpha': 1, 'reg_lambda': 0.1, 'objective': 'reg:squarederror', 'random_state': 42, 'n_jobs': -1}
# Best RMSE for XGBoost with WilcoxonPruner: 13.487423246061319
# Correlation Coefficient for XGBoost with WilcoxonPruner: 0.9752645127370292
# Running Optuna for LightGBM with MedianPruner...
# Best MSE for LightGBM with MedianPruner: 296.16773711882354 with params: {'n_estimators': 500, 'learning_rate': 0.05, 'num_leaves': 31, 'max_depth': 3, 'min_child_samples': 5, 'subsample': 1.0, 'colsample_bytree': 0.9, 'reg_alpha': 1, 'reg_lambda': 0.1, 'min_child_weight': 0.001, 'bagging_freq': 1, 'objective': 'regression', 'random_state': 42, 'n_jobs': -1, 'verbose': -1}
# Best RMSE for LightGBM with MedianPruner: 17.209524604672364
# Correlation Coefficient for LightGBM with MedianPruner: 0.9609747835964374
# Running Optuna for LightGBM with NopPruner...
# Best MSE for LightGBM with NopPruner: 215.3766207390773 with params: {'n_estimators': 300, 'learning_rate': 0.05, 'num_leaves': 31, 'max_depth': 5, 'min_child_samples': 1, 'subsample': 0.5, 'colsample_bytree': 1.0, 'reg_alpha': 0, 'reg_lambda': 1, 'min_child_weight': 0.001, 'bagging_freq': 1, 'objective': 'regression', 'random_state': 42, 'n_jobs': -1, 'verbose': -1}
# Best RMSE for LightGBM with NopPruner: 14.675715339944329
# Correlation Coefficient for LightGBM with NopPruner: 0.9734955910992491
# Running Optuna for LightGBM with PatientPruner...
# Best MSE for LightGBM with PatientPruner: 167.35402407134174 with params: {'n_estimators': 200, 'learning_rate': 0.15, 'num_leaves': 31, 'max_depth': 3, 'min_child_samples': 1, 'subsample': 0.5, 'colsample_bytree': 1.0, 'reg_alpha': 0, 'reg_lambda': 0.1, 'min_child_weight': 1e-05, 'bagging_freq': 1, 'objective': 'regression', 'random_state': 42, 'n_jobs': -1, 'verbose': -1}
# Best RMSE for LightGBM with PatientPruner: 12.936538334165819
# Correlation Coefficient for LightGBM with PatientPruner: 0.9745954785310634
# Running Optuna for LightGBM with PercentilePruner...
# Best MSE for LightGBM with PercentilePruner: 293.8650080291949 with params: {'n_estimators': 300, 'learning_rate': 0.05, 'num_leaves': 63, 'max_depth': 3, 'min_child_samples': 5, 'subsample': 1.0, 'colsample_bytree': 0.7, 'reg_alpha': 0.01, 'reg_lambda': 0, 'min_child_weight': 1e-05, 'bagging_freq': 5, 'objective': 'regression', 'random_state': 42, 'n_jobs': -1, 'verbose': -1}
# Best RMSE for LightGBM with PercentilePruner: 17.142491301709764
# Correlation Coefficient for LightGBM with PercentilePruner: 0.9611865496667292
# Running Optuna for LightGBM with SuccessiveHalvingPruner...
# Best MSE for LightGBM with SuccessiveHalvingPruner: 275.3093325558832 with params: {'n_estimators': 400, 'learning_rate': 0.15, 'num_leaves': 63, 'max_depth': 3, 'min_child_samples': 1, 'subsample': 0.5, 'colsample_bytree': 0.9, 'reg_alpha': 0.1, 'reg_lambda': 1, 'min_child_weight': 1e-05, 'bagging_freq': 1, 'objective': 'regression', 'random_state': 42, 'n_jobs': -1, 'verbose': -1}
# Best RMSE for LightGBM with SuccessiveHalvingPruner: 16.59244805795345
# Correlation Coefficient for LightGBM with SuccessiveHalvingPruner: 0.9620427695672663
# Running Optuna for LightGBM with HyperbandPruner...
# Best MSE for LightGBM with HyperbandPruner: 209.74374926478094 with params: {'n_estimators': 400, 'learning_rate': 0.05, 'num_leaves': 15, 'max_depth': -1, 'min_child_samples': 1, 'subsample': 0.5, 'colsample_bytree': 1.0, 'reg_alpha': 0, 'reg_lambda': 1, 'min_child_weight': 1e-05, 'bagging_freq': 1, 'objective': 'regression', 'random_state': 42, 'n_jobs': -1, 'verbose': -1}
# Best RMSE for LightGBM with HyperbandPruner: 14.482532557007456
# Correlation Coefficient for LightGBM with HyperbandPruner: 0.9738477399976019
# Running Optuna for LightGBM with ThresholdPruner...
# Best MSE for LightGBM with ThresholdPruner: 212.94153243462407 with params: {'n_estimators': 400, 'learning_rate': 0.1, 'num_leaves': 63, 'max_depth': 7, 'min_child_samples': 1, 'subsample': 0.5, 'colsample_bytree': 1.0, 'reg_alpha': 0.01, 'reg_lambda': 1, 'min_child_weight': 1e-05, 'bagging_freq': 1, 'objective': 'regression', 'random_state': 42, 'n_jobs': -1, 'verbose': -1}
# Best RMSE for LightGBM with ThresholdPruner: 14.592516316065028
# Correlation Coefficient for LightGBM with ThresholdPruner: 0.9711176500321567
# Running Optuna for LightGBM with WilcoxonPruner...
# Best MSE for LightGBM with WilcoxonPruner: 252.41294416148253 with params: {'n_estimators': 400, 'learning_rate': 0.15, 'num_leaves': 63, 'max_depth': 3, 'min_child_samples': 1, 'subsample': 0.6, 'colsample_bytree': 0.7, 'reg_alpha': 0.01, 'reg_lambda': 0, 'min_child_weight': 0.1, 'bagging_freq': 1, 'objective': 'regression', 'random_state': 42, 'n_jobs': -1, 'verbose': -1}
# Best RMSE for LightGBM with WilcoxonPruner: 15.887509060941005
# Correlation Coefficient for LightGBM with WilcoxonPruner: 0.9627803015534268
# Running Optuna for GPBoost with MedianPruner...
# Best MSE for GPBoost with MedianPruner: 302.4539295475795 with params: {'n_estimators': 500, 'learning_rate': 0.15, 'max_depth': 3, 'num_leaves': 31, 'min_child_samples': 5, 'subsample': 0.5, 'colsample_bytree': 0.7, 'reg_alpha': 1.0, 'reg_lambda': 0.5, 'min_child_weight': 1e-05, 'random_state': 42, 'n_jobs': -1, 'verbose': -1}
# Best RMSE for GPBoost with MedianPruner: 17.391202648108596
# Correlation Coefficient for GPBoost with MedianPruner: 0.9600726743566298
# Running Optuna for GPBoost with NopPruner...
# Best MSE for GPBoost with NopPruner: 318.42534401423444 with params: {'n_estimators': 400, 'learning_rate': 0.1, 'max_depth': 5, 'num_leaves': 15, 'min_child_samples': 5, 'subsample': 1.0, 'colsample_bytree': 0.7, 'reg_alpha': 0.1, 'reg_lambda': 0.1, 'min_child_weight': 0.001, 'random_state': 42, 'n_jobs': -1, 'verbose': -1}
# Best RMSE for GPBoost with NopPruner: 17.844476568793898
# Correlation Coefficient for GPBoost with NopPruner: 0.9577871307865051
# Running Optuna for GPBoost with PatientPruner...
# Best MSE for GPBoost with PatientPruner: 301.8837684766541 with params: {'n_estimators': 200, 'learning_rate': 0.15, 'max_depth': 3, 'num_leaves': 31, 'min_child_samples': 5, 'subsample': 0.9, 'colsample_bytree': 0.7, 'reg_alpha': 0.5, 'reg_lambda': 1.0, 'min_child_weight': 0.01, 'random_state': 42, 'n_jobs': -1, 'verbose': -1}
# Best RMSE for GPBoost with PatientPruner: 17.374802688855322
# Correlation Coefficient for GPBoost with PatientPruner: 0.9606103230320533
# Running Optuna for GPBoost with PercentilePruner...
# Best MSE for GPBoost with PercentilePruner: 289.62136754581115 with params: {'n_estimators': 400, 'learning_rate': 0.05, 'max_depth': 3, 'num_leaves': 31, 'min_child_samples': 5, 'subsample': 1.0, 'colsample_bytree': 0.9, 'reg_alpha': 0, 'reg_lambda': 0, 'min_child_weight': 1e-05, 'random_state': 42, 'n_jobs': -1, 'verbose': -1}
# Best RMSE for GPBoost with PercentilePruner: 17.018265703232252
# Correlation Coefficient for GPBoost with PercentilePruner: 0.9616429547621224
# Running Optuna for GPBoost with SuccessiveHalvingPruner...
# Best MSE for GPBoost with SuccessiveHalvingPruner: 291.3976432243806 with params: {'n_estimators': 200, 'learning_rate': 0.15, 'max_depth': 3, 'num_leaves': 31, 'min_child_samples': 5, 'subsample': 1.0, 'colsample_bytree': 0.7, 'reg_alpha': 0.1, 'reg_lambda': 0, 'min_child_weight': 1e-05, 'random_state': 42, 'n_jobs': -1, 'verbose': -1}
# Best RMSE for GPBoost with SuccessiveHalvingPruner: 17.070373259667775
# Correlation Coefficient for GPBoost with SuccessiveHalvingPruner: 0.9602353463338138
# Running Optuna for GPBoost with HyperbandPruner...
# Best MSE for GPBoost with HyperbandPruner: 301.8639659290113 with params: {'n_estimators': 200, 'learning_rate': 0.1, 'max_depth': 3, 'num_leaves': 31, 'min_child_samples': 5, 'subsample': 1.0, 'colsample_bytree': 1.0, 'reg_alpha': 0.5, 'reg_lambda': 0.1, 'min_child_weight': 0.01, 'random_state': 42, 'n_jobs': -1, 'verbose': -1}
# Best RMSE for GPBoost with HyperbandPruner: 17.37423281555221
# Correlation Coefficient for GPBoost with HyperbandPruner: 0.9598904538371217
# Running Optuna for GPBoost with ThresholdPruner...
# Best MSE for GPBoost with ThresholdPruner: 291.7690052454734 with params: {'n_estimators': 300, 'learning_rate': 0.15, 'max_depth': 3, 'num_leaves': 63, 'min_child_samples': 5, 'subsample': 0.7, 'colsample_bytree': 1.0, 'reg_alpha': 0.5, 'reg_lambda': 0, 'min_child_weight': 1e-05, 'random_state': 42, 'n_jobs': -1, 'verbose': -1}
# Best RMSE for GPBoost with ThresholdPruner: 17.081247180621016
# Correlation Coefficient for GPBoost with ThresholdPruner: 0.9628685814302016
# Running Optuna for GPBoost with WilcoxonPruner...
# Best MSE for GPBoost with WilcoxonPruner: 309.8384756819266 with params: {'n_estimators': 500, 'learning_rate': 0.1, 'max_depth': 3, 'num_leaves': 63, 'min_child_samples': 5, 'subsample': 1.0, 'colsample_bytree': 0.9, 'reg_alpha': 0.1, 'reg_lambda': 0.5, 'min_child_weight': 0.001, 'random_state': 42, 'n_jobs': -1, 'verbose': -1}
# Best RMSE for GPBoost with WilcoxonPruner: 17.60222928159745
# Correlation Coefficient for GPBoost with WilcoxonPruner: 0.9576966752619608
# Running Optuna for CatBoost with MedianPruner...
# Best MSE for CatBoost with MedianPruner: 383.597014990092 with params: {'iterations': 1000, 'learning_rate': 0.1, 'depth': 4, 'l2_leaf_reg': 9, 'border_count': 128, 'min_data_in_leaf': 1, 'rsm': 0.6, 'bagging_temperature': 1, 'random_seed': 42, 'verbose': 0}
# Best RMSE for CatBoost with MedianPruner: 19.585632871829596
# Correlation Coefficient for CatBoost with MedianPruner: 0.9504320068494378
# Running Optuna for CatBoost with NopPruner...
# Best MSE for CatBoost with NopPruner: 347.4429012205738 with params: {'iterations': 1000, 'learning_rate': 0.03, 'depth': 4, 'l2_leaf_reg': 5, 'border_count': 32, 'min_data_in_leaf': 20, 'rsm': 0.6, 'bagging_temperature': 10, 'random_seed': 42, 'verbose': 0}
# Best RMSE for CatBoost with NopPruner: 18.63982031084457
# Correlation Coefficient for CatBoost with NopPruner: 0.9614771149420601
# Running Optuna for CatBoost with PatientPruner...
# Best MSE for CatBoost with PatientPruner: 381.4352001178893 with params: {'iterations': 200, 'learning_rate': 0.1, 'depth': 4, 'l2_leaf_reg': 3, 'border_count': 128, 'min_data_in_leaf': 5, 'rsm': 0.8, 'bagging_temperature': 1, 'random_seed': 42, 'verbose': 0}
# Best RMSE for CatBoost with PatientPruner: 19.530366103017354
# Correlation Coefficient for CatBoost with PatientPruner: 0.9571259157623251
# Running Optuna for CatBoost with PercentilePruner...
# Best MSE for CatBoost with PercentilePruner: 352.7919134205213 with params: {'iterations': 1000, 'learning_rate': 0.05, 'depth': 4, 'l2_leaf_reg': 3, 'border_count': 32, 'min_data_in_leaf': 1, 'rsm': 0.8, 'bagging_temperature': 0, 'random_seed': 42, 'verbose': 0}
# Best RMSE for CatBoost with PercentilePruner: 18.782755746176367
# Correlation Coefficient for CatBoost with PercentilePruner: 0.9609618632008907
# Running Optuna for CatBoost with SuccessiveHalvingPruner...
# Best MSE for CatBoost with SuccessiveHalvingPruner: 376.2222721954891 with params: {'iterations': 1000, 'learning_rate': 0.05, 'depth': 4, 'l2_leaf_reg': 3, 'border_count': 128, 'min_data_in_leaf': 20, 'rsm': 0.6, 'bagging_temperature': 10, 'random_seed': 42, 'verbose': 0}
# Best RMSE for CatBoost with SuccessiveHalvingPruner: 19.39644998950811
# Correlation Coefficient for CatBoost with SuccessiveHalvingPruner: 0.9536838656258818
# Running Optuna for CatBoost with HyperbandPruner...
# Best MSE for CatBoost with HyperbandPruner: 352.7919134205213 with params: {'iterations': 1000, 'learning_rate': 0.05, 'depth': 4, 'l2_leaf_reg': 3, 'border_count': 32, 'min_data_in_leaf': 1, 'rsm': 0.8, 'bagging_temperature': 0, 'random_seed': 42, 'verbose': 0}
# Best RMSE for CatBoost with HyperbandPruner: 18.782755746176367
# Correlation Coefficient for CatBoost with HyperbandPruner: 0.9609618632008907
# Running Optuna for CatBoost with ThresholdPruner...
# Best MSE for CatBoost with ThresholdPruner: 364.6500962303509 with params: {'iterations': 1000, 'learning_rate': 0.1, 'depth': 4, 'l2_leaf_reg': 7, 'border_count': 32, 'min_data_in_leaf': 1, 'rsm': 0.8, 'bagging_temperature': 1, 'random_seed': 42, 'verbose': 0}
# Best RMSE for CatBoost with ThresholdPruner: 19.09581357864469
# Correlation Coefficient for CatBoost with ThresholdPruner: 0.9615043644058586
# Running Optuna for CatBoost with WilcoxonPruner...
# Best MSE for CatBoost with WilcoxonPruner: 363.24580555149436 with params: {'iterations': 1000, 'learning_rate': 0.03, 'depth': 4, 'l2_leaf_reg': 7, 'border_count': 128, 'min_data_in_leaf': 5, 'rsm': 0.8, 'bagging_temperature': 1, 'random_seed': 42, 'verbose': 0}
# Best RMSE for CatBoost with WilcoxonPruner: 19.05900851438748
# Correlation Coefficient for CatBoost with WilcoxonPruner: 0.9612932773075077
# Running Optuna for NGBoost with MedianPruner...
# Best MSE for NGBoost with MedianPruner: 208.6206854916466 with params: {'n_estimators': 200, 'learning_rate': 0.05, 'natural_gradient': True, 'minibatch_frac': 0.5, 'col_sample': 0.7, 'Dist': <class 'ngboost.distns.normal.Normal'>, 'Score': <class 'ngboost.scores.LogScore'>, 'random_state': 42, 'verbose': 0}
# Best RMSE for NGBoost with MedianPruner: 14.443707470440081
# Correlation Coefficient for NGBoost with MedianPruner: 0.972322539208482
# Running Optuna for NGBoost with NopPruner...
# Best MSE for NGBoost with NopPruner: 220.97018702137282 with params: {'n_estimators': 500, 'learning_rate': 0.01, 'natural_gradient': True, 'minibatch_frac': 0.5, 'col_sample': 0.9, 'Dist': <class 'ngboost.distns.normal.Normal'>, 'Score': <class 'ngboost.scores.LogScore'>, 'random_state': 42, 'verbose': 0}
# Best RMSE for NGBoost with NopPruner: 14.865065994517913
# Correlation Coefficient for NGBoost with NopPruner: 0.9723792362495827
# Running Optuna for NGBoost with PatientPruner...
# Best MSE for NGBoost with PatientPruner: 192.560849013683 with params: {'n_estimators': 500, 'learning_rate': 0.01, 'natural_gradient': True, 'minibatch_frac': 0.5, 'col_sample': 1.0, 'Dist': <class 'ngboost.distns.normal.Normal'>, 'Score': <class 'ngboost.scores.LogScore'>, 'random_state': 42, 'verbose': 0}
# Best RMSE for NGBoost with PatientPruner: 13.876629598489792
# Correlation Coefficient for NGBoost with PatientPruner: 0.9752386717656648
# Running Optuna for NGBoost with PercentilePruner...
# Best MSE for NGBoost with PercentilePruner: 238.07413166136223 with params: {'n_estimators': 500, 'learning_rate': 0.03, 'natural_gradient': True, 'minibatch_frac': 0.5, 'col_sample': 0.9, 'Dist': <class 'ngboost.distns.normal.Normal'>, 'Score': <class 'ngboost.scores.LogScore'>, 'random_state': 42, 'verbose': 0}
# Best RMSE for NGBoost with PercentilePruner: 15.429651054426417
# Correlation Coefficient for NGBoost with PercentilePruner: 0.9681571443145065
# Running Optuna for NGBoost with SuccessiveHalvingPruner...
# Best MSE for NGBoost with SuccessiveHalvingPruner: 205.8348672055246 with params: {'n_estimators': 500, 'learning_rate': 0.01, 'natural_gradient': True, 'minibatch_frac': 0.5, 'col_sample': 1.0, 'Dist': <class 'ngboost.distns.normal.Normal'>, 'Score': <class 'ngboost.scores.LogScore'>, 'random_state': 42, 'verbose': 0}
# Best RMSE for NGBoost with SuccessiveHalvingPruner: 14.346946267604288
# Correlation Coefficient for NGBoost with SuccessiveHalvingPruner: 0.9737618718364464
# Running Optuna for NGBoost with HyperbandPruner...
# Best MSE for NGBoost with HyperbandPruner: 217.94197670619747 with params: {'n_estimators': 1000, 'learning_rate': 0.01, 'natural_gradient': True, 'minibatch_frac': 0.5, 'col_sample': 0.7, 'Dist': <class 'ngboost.distns.normal.Normal'>, 'Score': <class 'ngboost.scores.LogScore'>, 'random_state': 42, 'verbose': 0}
# Best RMSE for NGBoost with HyperbandPruner: 14.762858012803532
# Correlation Coefficient for NGBoost with HyperbandPruner: 0.9709712414950974
# Running Optuna for NGBoost with ThresholdPruner...
# Best MSE for NGBoost with ThresholdPruner: 192.70590804151243 with params: {'n_estimators': 1000, 'learning_rate': 0.01, 'natural_gradient': True, 'minibatch_frac': 0.5, 'col_sample': 0.9, 'Dist': <class 'ngboost.distns.normal.Normal'>, 'Score': <class 'ngboost.scores.LogScore'>, 'random_state': 42, 'verbose': 0}
# Best RMSE for NGBoost with ThresholdPruner: 13.881855352996315
# Correlation Coefficient for NGBoost with ThresholdPruner: 0.9745085372253655
# Running Optuna for NGBoost with WilcoxonPruner...
# Best MSE for NGBoost with WilcoxonPruner: 181.73374322211725 with params: {'n_estimators': 1000, 'learning_rate': 0.01, 'natural_gradient': True, 'minibatch_frac': 0.5, 'col_sample': 1.0, 'Dist': <class 'ngboost.distns.normal.Normal'>, 'Score': <class 'ngboost.scores.LogScore'>, 'random_state': 42, 'verbose': 0}
# Best RMSE for NGBoost with WilcoxonPruner: 13.480865818711989
# Correlation Coefficient for NGBoost with WilcoxonPruner: 0.9768919590123354
# Running Optuna for HistGradientBoosting with MedianPruner...
# Best MSE for HistGradientBoosting with MedianPruner: 306.9466510692115 with params: {'learning_rate': 0.1, 'max_iter': 300, 'max_depth': 3, 'min_samples_leaf': 5, 'max_leaf_nodes': 31, 'l2_regularization': 0.5, 'max_bins': 128, 'early_stopping': False, 'validation_fraction': 0.1, 'n_iter_no_change': 5, 'loss': 'squared_error', 'random_state': 42, 'verbose': 0}
# Best RMSE for HistGradientBoosting with MedianPruner: 17.5198930096394
# Correlation Coefficient for HistGradientBoosting with MedianPruner: 0.9571560877136178
# Running Optuna for HistGradientBoosting with NopPruner...
# Best MSE for HistGradientBoosting with NopPruner: 309.71048974232986 with params: {'learning_rate': 0.15, 'max_iter': 100, 'max_depth': 3, 'min_samples_leaf': 5, 'max_leaf_nodes': 15, 'l2_regularization': 0.5, 'max_bins': 255, 'early_stopping': False, 'validation_fraction': 0.2, 'n_iter_no_change': 5, 'loss': 'squared_error', 'random_state': 42, 'verbose': 0}
# Best RMSE for HistGradientBoosting with NopPruner: 17.598593402381052
# Correlation Coefficient for HistGradientBoosting with NopPruner: 0.9582676889706158
# Running Optuna for HistGradientBoosting with PatientPruner...
# Best MSE for HistGradientBoosting with PatientPruner: 305.50458250552157 with params: {'learning_rate': 0.1, 'max_iter': 200, 'max_depth': 3, 'min_samples_leaf': 5, 'max_leaf_nodes': 15, 'l2_regularization': 0.5, 'max_bins': 255, 'early_stopping': False, 'validation_fraction': 0.1, 'n_iter_no_change': 10, 'loss': 'squared_error', 'random_state': 42, 'verbose': 0}
# Best RMSE for HistGradientBoosting with PatientPruner: 17.478689381802102
# Correlation Coefficient for HistGradientBoosting with PatientPruner: 0.957444692058178
# Running Optuna for HistGradientBoosting with PercentilePruner...
# Best MSE for HistGradientBoosting with PercentilePruner: 336.1044050556328 with params: {'learning_rate': 0.15, 'max_iter': 200, 'max_depth': 7, 'min_samples_leaf': 5, 'max_leaf_nodes': 15, 'l2_regularization': 0.1, 'max_bins': 128, 'early_stopping': False, 'validation_fraction': 0.1, 'n_iter_no_change': 5, 'loss': 'squared_error', 'random_state': 42, 'verbose': 0}
# Best RMSE for HistGradientBoosting with PercentilePruner: 18.333150439998924
# Correlation Coefficient for HistGradientBoosting with PercentilePruner: 0.9541352668559412
# Running Optuna for HistGradientBoosting with SuccessiveHalvingPruner...
# Best MSE for HistGradientBoosting with SuccessiveHalvingPruner: 310.15497272579285 with params: {'learning_rate': 0.15, 'max_iter': 200, 'max_depth': 3, 'min_samples_leaf': 5, 'max_leaf_nodes': 15, 'l2_regularization': 0.5, 'max_bins': 64, 'early_stopping': False, 'validation_fraction': 0.2, 'n_iter_no_change': 5, 'loss': 'squared_error', 'random_state': 42, 'verbose': 0}
# Best RMSE for HistGradientBoosting with SuccessiveHalvingPruner: 17.611217241457016
# Correlation Coefficient for HistGradientBoosting with SuccessiveHalvingPruner: 0.9578779385722576
# Running Optuna for HistGradientBoosting with HyperbandPruner...
# Best MSE for HistGradientBoosting with HyperbandPruner: 310.15497272579285 with params: {'learning_rate': 0.15, 'max_iter': 200, 'max_depth': 3, 'min_samples_leaf': 5, 'max_leaf_nodes': None, 'l2_regularization': 0.5, 'max_bins': 255, 'early_stopping': False, 'validation_fraction': 0.1, 'n_iter_no_change': 15, 'loss': 'squared_error', 'random_state': 42, 'verbose': 0}
# Best RMSE for HistGradientBoosting with HyperbandPruner: 17.611217241457016
# Correlation Coefficient for HistGradientBoosting with HyperbandPruner: 0.9578779385722576
# Running Optuna for HistGradientBoosting with ThresholdPruner...
# Best MSE for HistGradientBoosting with ThresholdPruner: 308.0584051247876 with params: {'learning_rate': 0.1, 'max_iter': 400, 'max_depth': 3, 'min_samples_leaf': 5, 'max_leaf_nodes': 15, 'l2_regularization': 1.0, 'max_bins': 128, 'early_stopping': False, 'validation_fraction': 0.2, 'n_iter_no_change': 5, 'loss': 'squared_error', 'random_state': 42, 'verbose': 0}
# Best RMSE for HistGradientBoosting with ThresholdPruner: 17.551592666330528
# Correlation Coefficient for HistGradientBoosting with ThresholdPruner: 0.9571352264254247
# Running Optuna for HistGradientBoosting with WilcoxonPruner...
# Best MSE for HistGradientBoosting with WilcoxonPruner: 308.2494075545725 with params: {'learning_rate': 0.1, 'max_iter': 500, 'max_depth': 3, 'min_samples_leaf': 5, 'max_leaf_nodes': 31, 'l2_regularization': 1.0, 'max_bins': 64, 'early_stopping': False, 'validation_fraction': 0.2, 'n_iter_no_change': 5, 'loss': 'squared_error', 'random_state': 42, 'verbose': 0}
# Best RMSE for HistGradientBoosting with WilcoxonPruner: 17.55703299406174
# Correlation Coefficient for HistGradientBoosting with WilcoxonPruner: 0.9571023046674804
# Running Optuna for PGBM with MedianPruner...
# Training on CPU
# Training on CPU
# Estimator 0/200, Train metric: 56.2353
# Estimator 1/200, Train metric: 55.9326
# Estimator 2/200, Train metric: 55.6006
# Estimator 3/200, Train metric: 55.2687
# Estimator 4/200, Train metric: 54.9022
# Estimator 5/200, Train metric: 54.6018
# Estimator 6/200, Train metric: 54.3049
# Estimator 7/200, Train metric: 54.0085
# Estimator 8/200, Train metric: 53.6983
# Estimator 9/200, Train metric: 53.3836
# Estimator 10/200, Train metric: 53.0687
# Estimator 11/200, Train metric: 52.7781
# Estimator 12/200, Train metric: 52.4851
# Estimator 13/200, Train metric: 52.1917
# Estimator 14/200, Train metric: 51.8844
# Estimator 15/200, Train metric: 51.5905
# Estimator 16/200, Train metric: 51.3217
# Estimator 17/200, Train metric: 51.0506
# Estimator 18/200, Train metric: 50.7811
# Estimator 19/200, Train metric: 50.4925
# Estimator 20/200, Train metric: 50.2321
# Estimator 21/200, Train metric: 49.9790
# Estimator 22/200, Train metric: 49.7792
# Estimator 23/200, Train metric: 49.4841
# Estimator 24/200, Train metric: 49.2233
# Estimator 25/200, Train metric: 48.9609
# Estimator 26/200, Train metric: 48.7030
# Estimator 27/200, Train metric: 48.4641
# Estimator 28/200, Train metric: 48.2471
# Estimator 29/200, Train metric: 47.9963
# Estimator 30/200, Train metric: 47.7850
# Estimator 31/200, Train metric: 47.5493
# Estimator 32/200, Train metric: 47.3211
# Estimator 33/200, Train metric: 47.1095
# Estimator 34/200, Train metric: 46.8703
# Estimator 35/200, Train metric: 46.6071
# Estimator 36/200, Train metric: 46.3524
# Estimator 37/200, Train metric: 46.1469
# Estimator 38/200, Train metric: 45.9261
# Estimator 39/200, Train metric: 45.7128
# Estimator 40/200, Train metric: 45.4742
# Estimator 41/200, Train metric: 45.2264
# Estimator 42/200, Train metric: 44.9901
# Estimator 43/200, Train metric: 44.7657
# Estimator 44/200, Train metric: 44.5667
# Estimator 45/200, Train metric: 44.3872
# Estimator 46/200, Train metric: 44.1664
# Estimator 47/200, Train metric: 43.9586
# Estimator 48/200, Train metric: 43.7429
# Estimator 49/200, Train metric: 43.5677
# Estimator 50/200, Train metric: 43.3899
# Estimator 51/200, Train metric: 43.1773
# Estimator 52/200, Train metric: 42.9835
# Estimator 53/200, Train metric: 42.8095
# Estimator 54/200, Train metric: 42.6059
# Estimator 55/200, Train metric: 42.3998
# Estimator 56/200, Train metric: 42.1835
# Estimator 57/200, Train metric: 41.9864
# Estimator 58/200, Train metric: 41.7757
# Estimator 59/200, Train metric: 41.5545
# Estimator 60/200, Train metric: 41.4048
# Estimator 61/200, Train metric: 41.2034
# Estimator 62/200, Train metric: 41.0604
# Estimator 63/200, Train metric: 40.9132
# Estimator 64/200, Train metric: 40.7350
# Estimator 65/200, Train metric: 40.5393
# Estimator 66/200, Train metric: 40.3415
# Estimator 67/200, Train metric: 40.1594
# Estimator 68/200, Train metric: 39.9694
# Estimator 69/200, Train metric: 39.7678
# Estimator 70/200, Train metric: 39.6167
# Estimator 71/200, Train metric: 39.4576
# Estimator 72/200, Train metric: 39.2710
# Estimator 73/200, Train metric: 39.0869
# Estimator 74/200, Train metric: 38.9329
# Estimator 75/200, Train metric: 38.7701
# Estimator 76/200, Train metric: 38.6492
# Estimator 77/200, Train metric: 38.4950
# Estimator 78/200, Train metric: 38.3388
# Estimator 79/200, Train metric: 38.1862
# Estimator 80/200, Train metric: 38.0184
# Estimator 81/200, Train metric: 37.9023
# Estimator 82/200, Train metric: 37.7541
# Estimator 83/200, Train metric: 37.6120
# Estimator 84/200, Train metric: 37.4535
# Estimator 85/200, Train metric: 37.3015
# Estimator 86/200, Train metric: 37.1487
# Estimator 87/200, Train metric: 37.0227
# Estimator 88/200, Train metric: 36.8727
# Estimator 89/200, Train metric: 36.7267
# Estimator 90/200, Train metric: 36.6310
# Estimator 91/200, Train metric: 36.4860
# Estimator 92/200, Train metric: 36.3311
# Estimator 93/200, Train metric: 36.1937
# Estimator 94/200, Train metric: 36.0509
# Estimator 95/200, Train metric: 35.9079
# Estimator 96/200, Train metric: 35.7658
# Estimator 97/200, Train metric: 35.6327
# Estimator 98/200, Train metric: 35.4903
# Estimator 99/200, Train metric: 35.3777
# Estimator 100/200, Train metric: 35.2816
# Estimator 101/200, Train metric: 35.1727
# Estimator 102/200, Train metric: 35.0729
# Estimator 103/200, Train metric: 34.9496
# Estimator 104/200, Train metric: 34.8286
# Estimator 105/200, Train metric: 34.6897
# Estimator 106/200, Train metric: 34.6019
# Estimator 107/200, Train metric: 34.5079
# Estimator 108/200, Train metric: 34.3763
# Estimator 109/200, Train metric: 34.2897
# Estimator 110/200, Train metric: 34.1663
# Estimator 111/200, Train metric: 34.0378
# Estimator 112/200, Train metric: 33.9281
# Estimator 113/200, Train metric: 33.8570
# Estimator 114/200, Train metric: 33.7758
# Estimator 115/200, Train metric: 33.6935
# Estimator 116/200, Train metric: 33.5557
# Estimator 117/200, Train metric: 33.4854
# Estimator 118/200, Train metric: 33.3828
# Estimator 119/200, Train metric: 33.2680
# Estimator 120/200, Train metric: 33.1642
# Estimator 121/200, Train metric: 33.0634
# Estimator 122/200, Train metric: 32.9401
# Estimator 123/200, Train metric: 32.8338
# Estimator 124/200, Train metric: 32.7173
# Estimator 125/200, Train metric: 32.5975
# Estimator 126/200, Train metric: 32.5104
# Estimator 127/200, Train metric: 32.3999
# Estimator 128/200, Train metric: 32.3255
# Estimator 129/200, Train metric: 32.2234
# Estimator 130/200, Train metric: 32.1352
# Estimator 131/200, Train metric: 32.0337
# Estimator 132/200, Train metric: 31.9265
# Estimator 133/200, Train metric: 31.8125
# Estimator 134/200, Train metric: 31.7069
# Estimator 135/200, Train metric: 31.6092
# Estimator 136/200, Train metric: 31.5079
# Estimator 137/200, Train metric: 31.4055
# Estimator 138/200, Train metric: 31.3171
# Estimator 139/200, Train metric: 31.2246
# Estimator 140/200, Train metric: 31.1219
# Estimator 141/200, Train metric: 31.0158
# Estimator 142/200, Train metric: 30.9555
# Estimator 143/200, Train metric: 30.8470
# Estimator 144/200, Train metric: 30.7527
# Estimator 145/200, Train metric: 30.6519
# Estimator 146/200, Train metric: 30.5541
# Estimator 147/200, Train metric: 30.4532
# Estimator 148/200, Train metric: 30.3549
# Estimator 149/200, Train metric: 30.2624
# Estimator 150/200, Train metric: 30.1921
# Estimator 151/200, Train metric: 30.1097
# Estimator 152/200, Train metric: 30.0297
# Estimator 153/200, Train metric: 29.9329
# Estimator 154/200, Train metric: 29.8490
# Estimator 155/200, Train metric: 29.7816
# Estimator 156/200, Train metric: 29.7058
# Estimator 157/200, Train metric: 29.6083
# Estimator 158/200, Train metric: 29.5531
# Estimator 159/200, Train metric: 29.4899
# Estimator 160/200, Train metric: 29.4378
# Estimator 161/200, Train metric: 29.3431
# Estimator 162/200, Train metric: 29.2852
# Estimator 163/200, Train metric: 29.1966
# Estimator 164/200, Train metric: 29.1378
# Estimator 165/200, Train metric: 29.0738
# Estimator 166/200, Train metric: 29.0266
# Estimator 167/200, Train metric: 28.9558
# Estimator 168/200, Train metric: 28.8947
# Estimator 169/200, Train metric: 28.8111
# Estimator 170/200, Train metric: 28.7766
# Estimator 171/200, Train metric: 28.7313
# Estimator 172/200, Train metric: 28.6571
# Estimator 173/200, Train metric: 28.5698
# Estimator 174/200, Train metric: 28.4842
# Estimator 175/200, Train metric: 28.3901
# Estimator 176/200, Train metric: 28.3260
# Estimator 177/200, Train metric: 28.2545
# Estimator 178/200, Train metric: 28.1801
# Estimator 179/200, Train metric: 28.1046
# Estimator 180/200, Train metric: 28.0235
# Estimator 181/200, Train metric: 27.9489
# Estimator 182/200, Train metric: 27.9077
# Estimator 183/200, Train metric: 27.8401
# Estimator 184/200, Train metric: 27.7850
# Estimator 185/200, Train metric: 27.7080
# Estimator 186/200, Train metric: 27.6643
# Estimator 187/200, Train metric: 27.5861
# Estimator 188/200, Train metric: 27.5379
# Estimator 189/200, Train metric: 27.4754
# Estimator 190/200, Train metric: 27.3947
# Estimator 191/200, Train metric: 27.3446
# Estimator 192/200, Train metric: 27.2683
# Estimator 193/200, Train metric: 27.2014
# Estimator 194/200, Train metric: 27.1350
# Estimator 195/200, Train metric: 27.0577
# Estimator 196/200, Train metric: 26.9857
# Estimator 197/200, Train metric: 26.9210
# Estimator 198/200, Train metric: 26.8613
# Estimator 199/200, Train metric: 26.7922
# Best MSE for PGBM with MedianPruner: 992.4083411512967 with params: {'n_estimators': 200, 'learning_rate': 0.01, 'max_leaves': 38, 'min_split_gain': 0.0, 'reg_lambda': 0.1, 'feature_fraction': 0.9, 'bagging_fraction': 0.9, 'tree_correlation': 0.3, 'min_data_in_leaf': 10, 'max_bin': 128, 'distribution': 'laplace'}
# Best RMSE for PGBM with MedianPruner: 31.502513251347054
# Correlation Coefficient for PGBM with MedianPruner: 0.894616031534982
# Running Optuna for PGBM with NopPruner...
# Training on CPU
# Training on CPU
# Estimator 0/200, Train metric: 52.5243
# Estimator 1/200, Train metric: 48.7519
# Estimator 2/200, Train metric: 45.4622
# Estimator 3/200, Train metric: 42.4180
# Estimator 4/200, Train metric: 39.6721
# Estimator 5/200, Train metric: 37.2664
# Estimator 6/200, Train metric: 35.0246
# Estimator 7/200, Train metric: 33.0398
# Estimator 8/200, Train metric: 31.4005
# Estimator 9/200, Train metric: 29.6280
# Estimator 10/200, Train metric: 27.9823
# Estimator 11/200, Train metric: 26.5606
# Estimator 12/200, Train metric: 25.1886
# Estimator 13/200, Train metric: 23.9332
# Estimator 14/200, Train metric: 22.9021
# Estimator 15/200, Train metric: 21.8283
# Estimator 16/200, Train metric: 20.9016
# Estimator 17/200, Train metric: 20.0287
# Estimator 18/200, Train metric: 19.2631
# Estimator 19/200, Train metric: 18.5687
# Estimator 20/200, Train metric: 17.9099
# Estimator 21/200, Train metric: 17.3446
# Estimator 22/200, Train metric: 16.8468
# Estimator 23/200, Train metric: 16.3903
# Estimator 24/200, Train metric: 15.9515
# Estimator 25/200, Train metric: 15.5664
# Estimator 26/200, Train metric: 15.1260
# Estimator 27/200, Train metric: 14.7579
# Estimator 28/200, Train metric: 14.4230
# Estimator 29/200, Train metric: 14.1150
# Estimator 30/200, Train metric: 13.8077
# Estimator 31/200, Train metric: 13.5596
# Estimator 32/200, Train metric: 13.3290
# Estimator 33/200, Train metric: 13.0994
# Estimator 34/200, Train metric: 12.8993
# Estimator 35/200, Train metric: 12.6965
# Estimator 36/200, Train metric: 12.3234
# Estimator 37/200, Train metric: 11.9873
# Estimator 38/200, Train metric: 11.6040
# Estimator 39/200, Train metric: 11.4321
# Estimator 40/200, Train metric: 11.2649
# Estimator 41/200, Train metric: 10.9717
# Estimator 42/200, Train metric: 10.6872
# Estimator 43/200, Train metric: 10.3899
# Estimator 44/200, Train metric: 10.1418
# Estimator 45/200, Train metric: 10.0102
# Estimator 46/200, Train metric: 9.8809
# Estimator 47/200, Train metric: 9.7478
# Estimator 48/200, Train metric: 9.6120
# Estimator 49/200, Train metric: 9.4913
# Estimator 50/200, Train metric: 9.3801
# Estimator 51/200, Train metric: 9.2663
# Estimator 52/200, Train metric: 9.1564
# Estimator 53/200, Train metric: 8.9401
# Estimator 54/200, Train metric: 8.6621
# Estimator 55/200, Train metric: 8.5682
# Estimator 56/200, Train metric: 8.4629
# Estimator 57/200, Train metric: 8.3741
# Estimator 58/200, Train metric: 8.2688
# Estimator 59/200, Train metric: 8.0674
# Estimator 60/200, Train metric: 7.9738
# Estimator 61/200, Train metric: 7.8635
# Estimator 62/200, Train metric: 7.7879
# Estimator 63/200, Train metric: 7.6984
# Estimator 64/200, Train metric: 7.6300
# Estimator 65/200, Train metric: 7.5416
# Estimator 66/200, Train metric: 7.4590
# Estimator 67/200, Train metric: 7.2709
# Estimator 68/200, Train metric: 7.1939
# Estimator 69/200, Train metric: 7.1200
# Estimator 70/200, Train metric: 7.0510
# Estimator 71/200, Train metric: 6.9851
# Estimator 72/200, Train metric: 6.8261
# Estimator 73/200, Train metric: 6.6585
# Estimator 74/200, Train metric: 6.6012
# ...
# Estimator 258/300, Train metric: 9.1784
# Estimator 259/300, Train metric: 9.1451
# Estimator 260/300, Train metric: 9.1114
# Estimator 261/300, Train metric: 9.0769
# Estimator 262/300, Train metric: 9.0494
# Estimator 263/300, Train metric: 8.9803
# Estimator 264/300, Train metric: 8.9350
# Estimator 265/300, Train metric: 8.9150
# Estimator 266/300, Train metric: 8.8855
# Estimator 267/300, Train metric: 8.8700
# Estimator 268/300, Train metric: 8.8451
# Estimator 269/300, Train metric: 8.8179
# Estimator 270/300, Train metric: 8.7946
# Estimator 271/300, Train metric: 8.7712
# Estimator 272/300, Train metric: 8.7382
# Estimator 273/300, Train metric: 8.7081
# Estimator 274/300, Train metric: 8.6512
# Estimator 275/300, Train metric: 8.5849
# Estimator 276/300, Train metric: 8.5485
# Estimator 277/300, Train metric: 8.5159
# Estimator 278/300, Train metric: 8.4716
# Estimator 279/300, Train metric: 8.4159
# Estimator 280/300, Train metric: 8.4096
# Estimator 281/300, Train metric: 8.3780
# Estimator 282/300, Train metric: 8.3360
# Estimator 283/300, Train metric: 8.3093
# Estimator 284/300, Train metric: 8.2837
# Estimator 285/300, Train metric: 8.2653
# Estimator 286/300, Train metric: 8.2502
# Estimator 287/300, Train metric: 8.2276
# Estimator 288/300, Train metric: 8.1917
# Estimator 289/300, Train metric: 8.1519
# Estimator 290/300, Train metric: 8.1261
# Estimator 291/300, Train metric: 8.0898
# Estimator 292/300, Train metric: 8.0707
# Estimator 293/300, Train metric: 8.0346
# Estimator 294/300, Train metric: 8.0149
# Estimator 295/300, Train metric: 7.9931
# Estimator 296/300, Train metric: 7.9716
# Estimator 297/300, Train metric: 7.9440
# Estimator 298/300, Train metric: 7.9217
# Estimator 299/300, Train metric: 7.9025
# Best MSE for PGBM with HyperbandPruner: 572.1861646272821 with params: {'n_estimators': 300, 'learning_rate': 0.05, 'max_leaves': 21, 'min_split_gain': 0.0, 'reg_lambda': 0.1, 'feature_fraction': 0.7, 'bagging_fraction': 0.9, 'tree_correlation': 0.3, 'min_data_in_leaf': 10, 'max_bin': 128, 'distribution': 'studentt'}
# Best RMSE for PGBM with HyperbandPruner: 23.920413136634618
# Correlation Coefficient for PGBM with HyperbandPruner: 0.913693102401316
# Running Optuna for PGBM with ThresholdPruner...
# Training on CPU
# Training on CPU
# Estimator 0/100, Train metric: 53.3198
# Estimator 1/100, Train metric: 50.1704
# Estimator 2/100, Train metric: 47.7832
# Estimator 3/100, Train metric: 44.5194
# Estimator 4/100, Train metric: 41.6251
# Estimator 5/100, Train metric: 38.9817
# Estimator 6/100, Train metric: 37.4275
# Estimator 7/100, Train metric: 35.2612
# Estimator 8/100, Train metric: 34.0276
# Estimator 9/100, Train metric: 31.9482
# Estimator 10/100, Train metric: 30.2254
# Estimator 11/100, Train metric: 28.5519
# Estimator 12/100, Train metric: 27.6122
# Estimator 13/100, Train metric: 26.6317
# Estimator 14/100, Train metric: 25.3513
# Estimator 15/100, Train metric: 23.9114
# Estimator 16/100, Train metric: 23.3696
# Estimator 17/100, Train metric: 22.9672
# Estimator 18/100, Train metric: 22.1373
# Estimator 19/100, Train metric: 21.7580
# Estimator 20/100, Train metric: 21.4500
# Estimator 21/100, Train metric: 21.1727
# Estimator 22/100, Train metric: 20.3884
# Estimator 23/100, Train metric: 20.0420
# Estimator 24/100, Train metric: 19.7254
# Estimator 25/100, Train metric: 18.8651
# Estimator 26/100, Train metric: 17.9492
# Estimator 27/100, Train metric: 17.7780
# Estimator 28/100, Train metric: 17.4432
# Estimator 29/100, Train metric: 16.7042
# Estimator 30/100, Train metric: 16.2943
# Estimator 31/100, Train metric: 15.6944
# Estimator 32/100, Train metric: 15.4083
# Estimator 33/100, Train metric: 14.8349
# Estimator 34/100, Train metric: 14.3306
# Estimator 35/100, Train metric: 13.7644
# Estimator 36/100, Train metric: 13.4740
# Estimator 37/100, Train metric: 13.3863
# Estimator 38/100, Train metric: 13.0706
# Estimator 39/100, Train metric: 12.7706
# Estimator 40/100, Train metric: 12.4866
# Estimator 41/100, Train metric: 12.1417
# Estimator 42/100, Train metric: 11.7666
# Estimator 43/100, Train metric: 11.7779
# Estimator 44/100, Train metric: 11.5704
# Estimator 45/100, Train metric: 11.5677
# Estimator 46/100, Train metric: 11.4048
# Estimator 47/100, Train metric: 11.2999
# Estimator 48/100, Train metric: 11.1247
# Estimator 49/100, Train metric: 11.1146
# Estimator 50/100, Train metric: 10.8307
# Estimator 51/100, Train metric: 10.5143
# Estimator 52/100, Train metric: 10.5762
# Estimator 53/100, Train metric: 10.4562
# Estimator 54/100, Train metric: 10.4316
# Estimator 55/100, Train metric: 10.2248
# Estimator 56/100, Train metric: 10.2107
# Estimator 57/100, Train metric: 10.1210
# Estimator 58/100, Train metric: 9.9219
# Estimator 59/100, Train metric: 9.7239
# Estimator 60/100, Train metric: 9.7102
# Estimator 61/100, Train metric: 9.6112
# Estimator 62/100, Train metric: 9.5036
# Estimator 63/100, Train metric: 9.3699
# Estimator 64/100, Train metric: 9.3705
# Estimator 65/100, Train metric: 9.2170
# Estimator 66/100, Train metric: 8.8572
# Estimator 67/100, Train metric: 8.8548
# Estimator 68/100, Train metric: 8.6880
# Estimator 69/100, Train metric: 8.5660
# Estimator 70/100, Train metric: 8.4318
# Estimator 71/100, Train metric: 8.3326
# Estimator 72/100, Train metric: 8.2678
# Estimator 73/100, Train metric: 8.1295
# Estimator 74/100, Train metric: 8.1313
# Estimator 75/100, Train metric: 8.0716
# Estimator 76/100, Train metric: 7.9787
# Estimator 77/100, Train metric: 7.8701
# Estimator 78/100, Train metric: 7.8880
# Estimator 79/100, Train metric: 7.7581
# Estimator 80/100, Train metric: 7.8031
# Estimator 81/100, Train metric: 7.5601
# Estimator 82/100, Train metric: 7.4438
# Estimator 83/100, Train metric: 7.3612
# Estimator 84/100, Train metric: 7.1685
# Estimator 85/100, Train metric: 7.1801
# Estimator 86/100, Train metric: 7.0151
# Estimator 87/100, Train metric: 6.9793
# Estimator 88/100, Train metric: 6.9474
# Estimator 89/100, Train metric: 6.9183
# Estimator 90/100, Train metric: 6.9023
# Estimator 91/100, Train metric: 6.8091
# Estimator 92/100, Train metric: 6.7193
# Estimator 93/100, Train metric: 6.6850
# Estimator 94/100, Train metric: 6.5879
# Estimator 95/100, Train metric: 6.4983
# Estimator 96/100, Train metric: 6.4828
# Estimator 97/100, Train metric: 6.4484
# Estimator 98/100, Train metric: 6.4092
# Estimator 99/100, Train metric: 6.3532
# Best MSE for PGBM with ThresholdPruner: 262.60126970395567 with params: {'n_estimators': 100, 'learning_rate': 0.1, 'max_leaves': 47, 'min_split_gain': 0.0, 'reg_lambda': 1.0, 'feature_fraction': 0.9, 'bagging_fraction': 0.5, 'tree_correlation': 0.3, 'min_data_in_leaf': 3, 'max_bin': 128, 'distribution': 'laplace'}
# Best RMSE for PGBM with ThresholdPruner: 16.204976695569655
# Correlation Coefficient for PGBM with ThresholdPruner: 0.9605348672424883
# Running Optuna for PGBM with WilcoxonPruner...
# Training on CPU
# Training on CPU
# Estimator 0/200, Train metric: 55.3062
# Estimator 1/200, Train metric: 54.0835
# Estimator 2/200, Train metric: 52.9248
# Estimator 3/200, Train metric: 51.8280
# Estimator 4/200, Train metric: 50.7904
# Estimator 5/200, Train metric: 49.8084
# Estimator 6/200, Train metric: 48.8787
# Estimator 7/200, Train metric: 48.0012
# Estimator 8/200, Train metric: 47.1735
# Estimator 9/200, Train metric: 46.3914
# Estimator 10/200, Train metric: 45.5490
# Estimator 11/200, Train metric: 44.7411
# Estimator 12/200, Train metric: 43.9751
# Estimator 13/200, Train metric: 43.2238
# Estimator 14/200, Train metric: 42.4885
# Estimator 15/200, Train metric: 41.7983
# Estimator 16/200, Train metric: 41.1882
# Estimator 17/200, Train metric: 40.5330
# Estimator 18/200, Train metric: 39.8906
# Estimator 19/200, Train metric: 39.2889
# Estimator 20/200, Train metric: 38.6960
# Estimator 21/200, Train metric: 38.1182
# Estimator 22/200, Train metric: 37.5752
# Estimator 23/200, Train metric: 37.0356
# Estimator 24/200, Train metric: 36.5160
# Estimator 25/200, Train metric: 36.0188
# Estimator 26/200, Train metric: 35.5939
# Estimator 27/200, Train metric: 35.1163
# Estimator 28/200, Train metric: 34.6685
# Estimator 29/200, Train metric: 34.2219
# Estimator 30/200, Train metric: 33.8493
# Estimator 31/200, Train metric: 33.4325
# Estimator 32/200, Train metric: 33.0545
# Estimator 33/200, Train metric: 32.6559
# Estimator 34/200, Train metric: 32.3301
# Estimator 35/200, Train metric: 31.9566
# Estimator 36/200, Train metric: 31.6534
# Estimator 37/200, Train metric: 31.3051
# Estimator 38/200, Train metric: 30.9581
# Estimator 39/200, Train metric: 30.5798
# Estimator 40/200, Train metric: 30.3071
# Estimator 41/200, Train metric: 29.9990
# Estimator 42/200, Train metric: 29.6868
# Estimator 43/200, Train metric: 29.3489
# Estimator 44/200, Train metric: 29.0733
# Estimator 45/200, Train metric: 28.8298
# Estimator 46/200, Train metric: 28.5445
# Estimator 47/200, Train metric: 28.2579
# Estimator 48/200, Train metric: 28.0293
# Estimator 49/200, Train metric: 27.7794
# Estimator 50/200, Train metric: 27.5109
# Estimator 51/200, Train metric: 27.2961
# Estimator 52/200, Train metric: 27.0386
# Estimator 53/200, Train metric: 26.8095
# Estimator 54/200, Train metric: 26.5644
# Estimator 55/200, Train metric: 26.3633
# Estimator 56/200, Train metric: 26.1289
# Estimator 57/200, Train metric: 25.8993
# Estimator 58/200, Train metric: 25.7113
# Estimator 59/200, Train metric: 25.4906
# Estimator 60/200, Train metric: 25.2771
# Estimator 61/200, Train metric: 25.1014
# Estimator 62/200, Train metric: 24.9090
# Estimator 63/200, Train metric: 24.7089
# Estimator 64/200, Train metric: 24.5129
# Estimator 65/200, Train metric: 24.3473
# Estimator 66/200, Train metric: 24.1568
# Estimator 67/200, Train metric: 23.9998
# Estimator 68/200, Train metric: 23.8178
# Estimator 69/200, Train metric: 23.6363
# Estimator 70/200, Train metric: 23.4876
# Estimator 71/200, Train metric: 23.3137
# Estimator 72/200, Train metric: 23.1469
# Estimator 73/200, Train metric: 23.0065
# Estimator 74/200, Train metric: 22.8395
# Estimator 75/200, Train metric: 22.6815
# Estimator 76/200, Train metric: 22.5476
# Estimator 77/200, Train metric: 22.3950
# Estimator 78/200, Train metric: 22.2420
# Estimator 79/200, Train metric: 22.1144
# Estimator 80/200, Train metric: 21.9748
# Estimator 81/200, Train metric: 21.8349
# Estimator 82/200, Train metric: 21.7150
# Estimator 83/200, Train metric: 21.5758
# Estimator 84/200, Train metric: 21.4449
# Estimator 85/200, Train metric: 21.3298
# Estimator 86/200, Train metric: 21.2062
# Estimator 87/200, Train metric: 21.1008
# Estimator 88/200, Train metric: 20.9840
# Estimator 89/200, Train metric: 20.8639
# Estimator 90/200, Train metric: 20.7465
# Estimator 91/200, Train metric: 20.6473
# Estimator 92/200, Train metric: 20.5346
# Estimator 93/200, Train metric: 20.4255
# Estimator 94/200, Train metric: 20.3315
# Estimator 95/200, Train metric: 20.2308
# Estimator 96/200, Train metric: 20.1243
# Estimator 97/200, Train metric: 20.0351
# Estimator 98/200, Train metric: 19.9394
# Estimator 99/200, Train metric: 19.8374
# Estimator 100/200, Train metric: 19.7516
# Estimator 101/200, Train metric: 19.6587
# Estimator 102/200, Train metric: 19.5588
# Estimator 103/200, Train metric: 19.4709
# Estimator 104/200, Train metric: 19.3780
# Estimator 105/200, Train metric: 19.2990
# Estimator 106/200, Train metric: 19.2074
# Estimator 107/200, Train metric: 19.1205
# Estimator 108/200, Train metric: 19.0397
# Estimator 109/200, Train metric: 18.9664
# Estimator 110/200, Train metric: 18.8780
# Estimator 111/200, Train metric: 18.7939
# Estimator 112/200, Train metric: 18.7144
# Estimator 113/200, Train metric: 18.6421
# Estimator 114/200, Train metric: 18.5600
# Estimator 115/200, Train metric: 18.4823
# Estimator 116/200, Train metric: 18.4114
# Estimator 117/200, Train metric: 18.3427
# Estimator 118/200, Train metric: 18.2763
# Estimator 119/200, Train metric: 18.1969
# Estimator 120/200, Train metric: 18.1224
# Estimator 121/200, Train metric: 18.0509
# Estimator 122/200, Train metric: 17.9853
# Estimator 123/200, Train metric: 17.9117
# Estimator 124/200, Train metric: 17.8482
# Estimator 125/200, Train metric: 17.7851
# Estimator 126/200, Train metric: 17.6409
# Estimator 127/200, Train metric: 17.5820
# Estimator 128/200, Train metric: 17.5207
# Estimator 129/200, Train metric: 17.4550
# Estimator 130/200, Train metric: 17.3878
# Estimator 131/200, Train metric: 17.3322
# Estimator 132/200, Train metric: 17.2733
# Estimator 133/200, Train metric: 17.2148
# Estimator 134/200, Train metric: 17.1623
# Estimator 135/200, Train metric: 17.1021
# Estimator 136/200, Train metric: 17.0452
# Estimator 137/200, Train metric: 16.9812
# Estimator 138/200, Train metric: 16.9319
# Estimator 139/200, Train metric: 16.8723
# Estimator 140/200, Train metric: 16.8193
# Estimator 141/200, Train metric: 16.7640
# Estimator 142/200, Train metric: 16.7105
# Estimator 143/200, Train metric: 16.6644
# Estimator 144/200, Train metric: 16.6053
# Estimator 145/200, Train metric: 16.5427
# Estimator 146/200, Train metric: 16.4930
# Estimator 147/200, Train metric: 16.4483
# Estimator 148/200, Train metric: 16.3970
# Estimator 149/200, Train metric: 16.2871
# Estimator 150/200, Train metric: 16.2355
# Estimator 151/200, Train metric: 16.1967
# Estimator 152/200, Train metric: 16.1421
# Estimator 153/200, Train metric: 16.0936
# Estimator 154/200, Train metric: 16.0568
# Estimator 155/200, Train metric: 16.0007
# Estimator 156/200, Train metric: 15.9543
# Estimator 157/200, Train metric: 15.8628
# Estimator 158/200, Train metric: 15.8133
# Estimator 159/200, Train metric: 15.7757
# Estimator 160/200, Train metric: 15.7236
# Estimator 161/200, Train metric: 15.6805
# Estimator 162/200, Train metric: 15.5960
# Estimator 163/200, Train metric: 15.5488
# Estimator 164/200, Train metric: 15.5021
# Estimator 165/200, Train metric: 15.4671
# Estimator 166/200, Train metric: 15.4229
# Estimator 167/200, Train metric: 15.3918
# Estimator 168/200, Train metric: 15.3078
# Estimator 169/200, Train metric: 15.2623
# Estimator 170/200, Train metric: 15.2210
# Estimator 171/200, Train metric: 15.1921
# Estimator 172/200, Train metric: 15.1489
# Estimator 173/200, Train metric: 15.1083
# Estimator 174/200, Train metric: 15.0307
# Estimator 175/200, Train metric: 14.9880
# Estimator 176/200, Train metric: 14.9458
# Estimator 177/200, Train metric: 14.9182
# Estimator 178/200, Train metric: 14.8787
# Estimator 179/200, Train metric: 14.8063
# Estimator 180/200, Train metric: 14.7640
# Estimator 181/200, Train metric: 14.7243
# Estimator 182/200, Train metric: 14.6978
# Estimator 183/200, Train metric: 14.6570
# Estimator 184/200, Train metric: 14.5850
# Estimator 185/200, Train metric: 14.5470
# Estimator 186/200, Train metric: 14.5086
# Estimator 187/200, Train metric: 14.4728
# Estimator 188/200, Train metric: 14.4056
# Estimator 189/200, Train metric: 14.3660
# Estimator 190/200, Train metric: 14.3417
# Estimator 191/200, Train metric: 14.3072
# Estimator 192/200, Train metric: 14.2690
# Estimator 193/200, Train metric: 14.2026
# Estimator 194/200, Train metric: 14.1673
# Estimator 195/200, Train metric: 14.1241
# Estimator 196/200, Train metric: 14.0895
# Estimator 197/200, Train metric: 14.0259
# Estimator 198/200, Train metric: 13.9930
# Estimator 199/200, Train metric: 13.9696
# Best MSE for PGBM with WilcoxonPruner: 583.1855919476949 with params: {'n_estimators': 200, 'learning_rate': 0.05, 'max_leaves': 42, 'min_split_gain': 0.1, 'reg_lambda': 5.0, 'feature_fraction': 1.0, 'bagging_fraction': 1.0, 'tree_correlation': 0.3, 'min_data_in_leaf': 10, 'max_bin': 128, 'distribution': 'normal'}
# Best RMSE for PGBM with WilcoxonPruner: 24.149235846040654
# Correlation Coefficient for PGBM with WilcoxonPruner: 0.916358980778455
# Created a new Excel file at: ./drive/MyDrive/water_analysis/test.xlsx
#
# Best model on test data: Gradient Boosting with WilcoxonPruner
# Test MSE: 145.8174616849565
# Test RMSE: 12.075490121935278
# Correlation Coefficient: 0.9799339191310297
# Best Parameters: {'loss': 'squared_error', 'learning_rate': 0.05, 'n_estimators': 300, 'subsample': 0.7, 'criterion': 'friedman_mse', 'min_samples_split': 10, 'min_samples_leaf': 0.01, 'min_weight_fraction_leaf': 0.01, 'max_depth': 7, 'min_impurity_decrease': 0.0, 'init': None, 'random_state': 42, 'max_features': None, 'alpha': 0.5, 'verbose': 0, 'max_leaf_nodes': None, 'warm_start': False, 'validation_fraction': 0.1, 'n_iter_no_change': None, 'tol': 0.001, 'ccp_alpha': 0.0}
# Pruner Used: WilcoxonPruner

# %%
best_scores_autosampler
# Out:
# {('Random Forest', 'MedianPruner'): {'best_score': 494.0832274465908,
#   'best_params': {'n_estimators': 100,
#    'criterion': 'squared_error',
#    'max_depth': 40,
#    'min_samples_split': 0.01,
#    'min_samples_leaf': 0.01,
#    'min_weight_fraction_leaf': 0.01,
#    'max_features': 1.0,
#    'max_leaf_nodes': 200,
#    'min_impurity_decrease': 0.0,
#    'n_jobs': -1,
#    'random_state': 42,
#    'verbose': 0,
#    'warm_start': False,
#    'ccp_alpha': 0.1},
#   'test_mse': 494.0832274465908,
#   'test_rmse': 22.227982981966466,
#   'test_corr_coef': 0.9562504266776625,
#   'pruner': 'MedianPruner'},
#  ('Random Forest', 'NopPruner'): {'best_score': 498.42412699059673,
#   'best_params': {'n_estimators': 700,
#    'criterion': 'squared_error',
#    'max_depth': 20,
#    'min_samples_split': 2,
#    'min_samples_leaf': 1,
#    'min_weight_fraction_leaf': 0.0,
#    'max_features': 0.5,
#    'max_leaf_nodes': 50,
#    'min_impurity_decrease': 0.01,
#    'n_jobs': -1,
#    'random_state': 42,
#    'verbose': 0,
#    'warm_start': False,
#    'ccp_alpha': 0.0},
#   'test_mse': 498.42412699059673,
#   'test_rmse': 22.325414374443238,
#   'test_corr_coef': 0.9565152609582364,
#   'pruner': 'NopPruner'},
#  ('Random Forest', 'PatientPruner'): {'best_score': 501.77203003955043,
#   'best_params': {'n_estimators': 300,
#    'criterion': 'squared_error',
#    'max_depth': 10,
#    'min_samples_split': 0.01,
#    'min_samples_leaf': 0.01,
#    'min_weight_fraction_leaf': 0.01,
#    'max_features': 1.0,
#    'max_leaf_nodes': 200,
#    'min_impurity_decrease': 0.01,
#    'n_jobs': -1,
#    'random_state': 42,
#    'verbose': 0,
#    'warm_start': False,
#    'ccp_alpha': 0.001},
#   'test_mse': 501.77203003955043,
#   'test_rmse': 22.400268526059023,
#   'test_corr_coef': 0.9577060428217671,
#   'pruner': 'PatientPruner'},
#  ('Random Forest', 'PercentilePruner'): {'best_score': 502.5656396305721,
#   'best_params': {'n_estimators': 300,
#    'criterion': 'absolute_error',
#    'max_depth': 10,
#    'min_samples_split': 2,
#    'min_samples_leaf': 1,
#    'min_weight_fraction_leaf': 0.0,
#    'max_features': 0.5,
#    'max_leaf_nodes': None,
#    'min_impurity_decrease': 0.01,
#    'n_jobs': -1,
#    'random_state': 42,
#    'verbose': 0,
#    'warm_start': False,
#    'ccp_alpha': 0.001},
#   'test_mse': 502.5656396305721,
#   'test_rmse': 22.417975814746793,
#   'test_corr_coef': 0.9544318450063605,
#   'pruner': 'PercentilePruner'},
#  ('Random Forest',
#   'SuccessiveHalvingPruner'): {'best_score': 499.70003183856176, 'best_params': {'n_estimators': 200,
#    'criterion': 'friedman_mse',
#    'max_depth': 30,
#    'min_samples_split': 2,
#    'min_samples_leaf': 1,
#    'min_weight_fraction_leaf': 0.01,
#    'max_features': 1.0,
#    'max_leaf_nodes': 50,
#    'min_impurity_decrease': 0.0,
#    'n_jobs': -1,
#    'random_state': 42,
#    'verbose': 0,
#    'warm_start': False,
#    'ccp_alpha': 0.01}, 'test_mse': 499.70003183856176, 'test_rmse': 22.353971276678372, 'test_corr_coef': 0.9555634577545703, 'pruner': 'SuccessiveHalvingPruner'},
#  ('Random Forest', 'HyperbandPruner'): {'best_score': 506.9664016421923,
#   'best_params': {'n_estimators': 300,
#    'criterion': 'friedman_mse',
#    'max_depth': 10,
#    'min_samples_split': 2,
#    'min_samples_leaf': 1,
#    'min_weight_fraction_leaf': 0.0,
#    'max_features': 1.0,
#    'max_leaf_nodes': 100,
#    'min_impurity_decrease': 0.1,
#    'n_jobs': -1,
#    'random_state': 42,
#    'verbose': 0,
#    'warm_start': False,
#    'ccp_alpha': 0.001},
#   'test_mse': 506.9664016421923,
#   'test_rmse': 22.515914408306678,
#   'test_corr_coef': 0.9565188484300761,
#   'pruner': 'HyperbandPruner'},
#  ('Random Forest', 'ThresholdPruner'): {'best_score': 499.0133409866187,
#   'best_params': {'n_estimators': 200,
#    'criterion': 'absolute_error',
#    'max_depth': 10,
#    'min_samples_split': 2,
#    'min_samples_leaf': 0.01,
#    'min_weight_fraction_leaf': 0.01,
#    'max_features': 1.0,
#    'max_leaf_nodes': 100,
#    'min_impurity_decrease': 0.2,
#    'n_jobs': -1,
#    'random_state': 42,
#    'verbose': 0,
#    'warm_start': False,
#    'ccp_alpha': 0.05},
#   'test_mse': 499.0133409866187,
#   'test_rmse': 22.33860651398423,
#   'test_corr_coef': 0.9581329488959802,
#   'pruner': 'ThresholdPruner'},
#  ('Random Forest', 'WilcoxonPruner'): {'best_score': 499.03317084662626,
#   'best_params': {'n_estimators': 700,
#    'criterion': 'squared_error',
#    'max_depth': 40,
#    'min_samples_split': 2,
#    'min_samples_leaf': 0.01,
#    'min_weight_fraction_leaf': 0.01,
#    'max_features': 0.5,
#    'max_leaf_nodes': 200,
#    'min_impurity_decrease': 0.2,
#    'n_jobs': -1,
#    'random_state': 42,
#    'verbose': 0,
#    'warm_start': False,
#    'ccp_alpha': 0.0},
#   'test_mse': 499.03317084662626,
#   'test_rmse': 22.3390503568667,
#   'test_corr_coef': 0.9564495763116471,
#   'pruner': 'WilcoxonPruner'},
#  ('Gradient Boosting', 'MedianPruner'): {'best_score': 191.0133084285086,
#   'best_params': {'loss': 'squared_error',
#    'learning_rate': 0.05,
#    'n_estimators': 200,
#    'subsample': 0.5,
#    'criterion': 'squared_error',
#    'min_samples_split': 2,
#    'min_samples_leaf': 0.01,
#    'min_weight_fraction_leaf': 0.01,
#    'max_depth': 3,
#    'min_impurity_decrease': 0.0,
#    'init': None,
#    'random_state': 42,
#    'max_features': None,
#    'alpha': 0.9,
#    'verbose': 0,
#    'max_leaf_nodes': None,
#    'warm_start': False,
#    'validation_fraction': 0.1,
#    'n_iter_no_change': 20,
#    'tol': 0.0001,
#    'ccp_alpha': 0.0},
#   'test_mse': 191.0133084285086,
#   'test_rmse': 13.820756434743672,
#   'test_corr_coef': 0.9745455081893564,
#   'pruner': 'MedianPruner'},
#  ('Gradient Boosting', 'NopPruner'): {'best_score': 176.67485993940775,
#   'best_params': {'loss': 'squared_error',
#    'learning_rate': 0.05,
#    'n_estimators': 300,
#    'subsample': 0.7,
#    'criterion': 'friedman_mse',
#    'min_samples_split': 5,
#    'min_samples_leaf': 1,
#    'min_weight_fraction_leaf': 0.0,
#    'max_depth': 5,
#    'min_impurity_decrease': 0.01,
#    'init': None,
#    'random_state': 42,
#    'max_features': None,
#    'alpha': 0.1,
#    'verbose': 0,
#    'max_leaf_nodes': 30,
#    'warm_start': False,
#    'validation_fraction': 0.1,
#    'n_iter_no_change': 10,
#    'tol': 0.0001,
#    'ccp_alpha': 0.0},
#   'test_mse': 176.67485993940775,
#   'test_rmse': 13.291909567079056,
#   'test_corr_coef': 0.9780654642635519,
#   'pruner': 'NopPruner'},
#  ('Gradient Boosting', 'PatientPruner'): {'best_score': 155.26382478955753,
#   'best_params': {'loss': 'squared_error',
#    'learning_rate': 0.05,
#    'n_estimators': 500,
#    'subsample': 0.7,
#    'criterion': 'friedman_mse',
#    'min_samples_split': 10,
#    'min_samples_leaf': 0.01,
#    'min_weight_fraction_leaf': 0.0,
#    'max_depth': 5,
#    'min_impurity_decrease': 0.1,
#    'init': None,
#    'random_state': 42,
#    'max_features': 0.5,
#    'alpha': 0.1,
#    'verbose': 0,
#    'max_leaf_nodes': 10,
#    'warm_start': False,
#    'validation_fraction': 0.1,
#    'n_iter_no_change': None,
#    'tol': 0.0001,
#    'ccp_alpha': 0.0},
#   'test_mse': 155.26382478955753,
#   'test_rmse': 12.460490551722172,
#   'test_corr_coef': 0.9800953042627318,
#   'pruner': 'PatientPruner'},
#  ('Gradient Boosting', 'PercentilePruner'): {'best_score': 169.34283962923186,
#   'best_params': {'loss': 'squared_error',
#    'learning_rate': 0.05,
#    'n_estimators': 100,
#    'subsample': 0.7,
#    'criterion': 'squared_error',
#    'min_samples_split': 10,
#    'min_samples_leaf': 1,
#    'min_weight_fraction_leaf': 0.01,
#    'max_depth': 3,
#    'min_impurity_decrease': 0.1,
#    'init': None,
#    'random_state': 42,
#    'max_features': None,
#    'alpha': 0.5,
#    'verbose': 0,
#    'max_leaf_nodes': 50,
#    'warm_start': False,
#    'validation_fraction': 0.1,
#    'n_iter_no_change': 10,
#    'tol': 0.0001,
#    'ccp_alpha': 0.0},
#   'test_mse': 169.34283962923186,
#   'test_rmse': 13.01317945888828,
#   'test_corr_coef': 0.9761672902842062,
#   'pruner': 'PercentilePruner'},
#  ('Gradient Boosting',
#   'SuccessiveHalvingPruner'): {'best_score': 177.32280622709055, 'best_params': {'loss': 'squared_error',
#    'learning_rate': 0.05,
#    'n_estimators': 700,
#    'subsample': 0.7,
#    'criterion': 'friedman_mse',
#    'min_samples_split': 10,
#    'min_samples_leaf': 0.01,
#    'min_weight_fraction_leaf': 0.0,
#    'max_depth': 7,
#    'min_impurity_decrease': 0.1,
#    'init': None,
#    'random_state': 42,
#    'max_features': 0.5,
#    'alpha': 0.9,
#    'verbose': 0,
#    'max_leaf_nodes': 30,
#    'warm_start': False,
#    'validation_fraction': 0.1,
#    'n_iter_no_change': None,
#    'tol': 0.0001,
#    'ccp_alpha': 0.01}, 'test_mse': 177.32280622709055, 'test_rmse': 13.316260970223231, 'test_corr_coef': 0.9787399487142573, 'pruner': 'SuccessiveHalvingPruner'},
#  ('Gradient Boosting', 'HyperbandPruner'): {'best_score': 161.03029266801352,
#   'best_params': {'loss': 'squared_error',
#    'learning_rate': 0.05,
#    'n_estimators': 300,
#    'subsample': 0.5,
#    'criterion': 'friedman_mse',
#    'min_samples_split': 10,
#    'min_samples_leaf': 1,
#    'min_weight_fraction_leaf': 0.05,
#    'max_depth': 3,
#    'min_impurity_decrease': 0.0,
#    'init': None,
#    'random_state': 42,
#    'max_features': None,
#    'alpha': 0.9,
#    'verbose': 0,
#    'max_leaf_nodes': 30,
#    'warm_start': False,
#    'validation_fraction': 0.1,
#    'n_iter_no_change': None,
#    'tol': 0.0001,
#    'ccp_alpha': 0.001},
#   'test_mse': 161.03029266801352,
#   'test_rmse': 12.689771182649967,
#   'test_corr_coef': 0.9762767640815191,
#   'pruner': 'HyperbandPruner'},
#  ('Gradient Boosting', 'ThresholdPruner'): {'best_score': 173.41940240454602,
#   'best_params': {'loss': 'squared_error',
#    'learning_rate': 0.2,
#    'n_estimators': 100,
#    'subsample': 0.9,
#    'criterion': 'friedman_mse',
#    'min_samples_split': 5,
#    'min_samples_leaf': 1,
#    'min_weight_fraction_leaf': 0.05,
#    'max_depth': 3,
#    'min_impurity_decrease': 0.0,
#    'init': None,
#    'random_state': 42,
#    'max_features': None,
#    'alpha': 0.9,
#    'verbose': 0,
#    'max_leaf_nodes': 10,
#    'warm_start': False,
#    'validation_fraction': 0.1,
#    'n_iter_no_change': None,
#    'tol': 0.0001,
#    'ccp_alpha': 0.0},
#   'test_mse': 173.41940240454602,
#   'test_rmse': 13.16888007404373,
#   'test_corr_coef': 0.979515687794808,
#   'pruner': 'ThresholdPruner'},
#  ('Gradient Boosting', 'WilcoxonPruner'): {'best_score': 145.8174616849565,
#   'best_params': {'loss': 'squared_error',
#    'learning_rate': 0.05,
#    'n_estimators': 300,
#    'subsample': 0.7,
#    'criterion': 'friedman_mse',
#    'min_samples_split': 10,
#    'min_samples_leaf': 0.01,
#    'min_weight_fraction_leaf': 0.01,
#    'max_depth': 7,
#    'min_impurity_decrease': 0.0,
#    'init': None,
#    'random_state': 42,
#    'max_features': None,
#    'alpha': 0.5,
#    'verbose': 0,
#    'max_leaf_nodes': None,
#    'warm_start': False,
#    'validation_fraction': 0.1,
#    'n_iter_no_change': None,
#    'tol': 0.001,
#    'ccp_alpha': 0.0},
#   'test_mse': 145.8174616849565,
#   'test_rmse': 12.075490121935278,
#   'test_corr_coef': 0.9799339191310297,
#   'pruner': 'WilcoxonPruner'},
#  ('XGBoost', 'MedianPruner'): {'best_score': 167.48354105000854,
#   'best_params': {'n_estimators': 400,
#    'learning_rate': 0.1,
#    'max_depth': 3,
#    'min_child_weight': 3,
#    'gamma': 0,
#    'subsample': 0.6,
#    'colsample_bytree': 0.9,
#    'colsample_bylevel': 0.5,
#    'reg_alpha': 0.01,
#    'reg_lambda': 0.1,
#    'objective': 'reg:squarederror',
#    'random_state': 42,
#    'n_jobs': -1},
#   'test_mse': 167.48354105000854,
#   'test_rmse': 12.941543225211147,
#   'test_corr_coef': 0.9773359945592573,
#   'pruner': 'MedianPruner'},
#  ('XGBoost', 'NopPruner'): {'best_score': 236.71268109376012,
#   'best_params': {'n_estimators': 300,
#    'learning_rate': 0.15,
#    'max_depth': 5,
#    'min_child_weight': 3,
#    'gamma': 0,
#    'subsample': 0.7,
#    'colsample_bytree': 0.9,
#    'colsample_bylevel': 0.9,
#    'reg_alpha': 0,
#    'reg_lambda': 0.1,
#    'objective': 'reg:squarederror',
#    'random_state': 42,
#    'n_jobs': -1},
#   'test_mse': 236.71268109376012,
#   'test_rmse': 15.385469804128833,
#   'test_corr_coef': 0.9659065395777474,
#   'pruner': 'NopPruner'},
#  ('XGBoost', 'PatientPruner'): {'best_score': 208.80286778526713,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.05,
#    'max_depth': 3,
#    'min_child_weight': 1,
#    'gamma': 1,
#    'subsample': 0.7,
#    'colsample_bytree': 0.9,
#    'colsample_bylevel': 0.7,
#    'reg_alpha': 1,
#    'reg_lambda': 1,
#    'objective': 'reg:squarederror',
#    'random_state': 42,
#    'n_jobs': -1},
#   'test_mse': 208.80286778526713,
#   'test_rmse': 14.450012726128207,
#   'test_corr_coef': 0.976663363418376,
#   'pruner': 'PatientPruner'},
#  ('XGBoost', 'PercentilePruner'): {'best_score': 222.43444086923606,
#   'best_params': {'n_estimators': 200,
#    'learning_rate': 0.1,
#    'max_depth': 3,
#    'min_child_weight': 3,
#    'gamma': 0,
#    'subsample': 0.9,
#    'colsample_bytree': 0.9,
#    'colsample_bylevel': 0.5,
#    'reg_alpha': 1,
#    'reg_lambda': 1,
#    'objective': 'reg:squarederror',
#    'random_state': 42,
#    'n_jobs': -1},
#   'test_mse': 222.43444086923606,
#   'test_rmse': 14.914236181220815,
#   'test_corr_coef': 0.9720838341949776,
#   'pruner': 'PercentilePruner'},
#  ('XGBoost', 'SuccessiveHalvingPruner'): {'best_score': 198.17237294214013,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.15,
#    'max_depth': 5,
#    'min_child_weight': 3,
#    'gamma': 1,
#    'subsample': 0.7,
#    'colsample_bytree': 0.9,
#    'colsample_bylevel': 0.7,
#    'reg_alpha': 0,
#    'reg_lambda': 0.1,
#    'objective': 'reg:squarederror',
#    'random_state': 42,
#    'n_jobs': -1},
#   'test_mse': 198.17237294214013,
#   'test_rmse': 14.077370952778795,
#   'test_corr_coef': 0.9709271450848449,
#   'pruner': 'SuccessiveHalvingPruner'},
#  ('XGBoost', 'HyperbandPruner'): {'best_score': 199.9752973212219,
#   'best_params': {'n_estimators': 300,
#    'learning_rate': 0.15,
#    'max_depth': 3,
#    'min_child_weight': 1,
#    'gamma': 0,
#    'subsample': 0.6,
#    'colsample_bytree': 0.9,
#    'colsample_bylevel': 0.7,
#    'reg_alpha': 0,
#    'reg_lambda': 0.1,
#    'objective': 'reg:squarederror',
#    'random_state': 42,
#    'n_jobs': -1},
#   'test_mse': 199.9752973212219,
#   'test_rmse': 14.141262225177138,
#   'test_corr_coef': 0.9727053213725442,
#   'pruner': 'HyperbandPruner'},
#  ('XGBoost', 'ThresholdPruner'): {'best_score': 212.36630646483607,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.05,
#    'max_depth': 3,
#    'min_child_weight': 1,
#    'gamma': 0.5,
#    'subsample': 0.5,
#    'colsample_bytree': 0.9,
#    'colsample_bylevel': 0.5,
#    'reg_alpha': 0,
#    'reg_lambda': 1,
#    'objective': 'reg:squarederror',
#    'random_state': 42,
#    'n_jobs': -1},
#   'test_mse': 212.36630646483607,
#   'test_rmse': 14.57279336520065,
#   'test_corr_coef': 0.9709231163297497,
#   'pruner': 'ThresholdPruner'},
#  ('XGBoost', 'WilcoxonPruner'): {'best_score': 181.91058581839525,
#   'best_params': {'n_estimators': 100,
#    'learning_rate': 0.1,
#    'max_depth': 3,
#    'min_child_weight': 1,
#    'gamma': 1,
#    'subsample': 0.6,
#    'colsample_bytree': 0.7,
#    'colsample_bylevel': 0.9,
#    'reg_alpha': 1,
#    'reg_lambda': 0.1,
#    'objective': 'reg:squarederror',
#    'random_state': 42,
#    'n_jobs': -1},
#   'test_mse': 181.91058581839525,
#   'test_rmse': 13.487423246061319,
#   'test_corr_coef': 0.9752645127370292,
#   'pruner': 'WilcoxonPruner'},
#  ('LightGBM', 'MedianPruner'): {'best_score': 296.16773711882354,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.05,
#    'num_leaves': 31,
#    'max_depth': 3,
#    'min_child_samples': 5,
#    'subsample': 1.0,
#    'colsample_bytree': 0.9,
#    'reg_alpha': 1,
#    'reg_lambda': 0.1,
#    'min_child_weight': 0.001,
#    'bagging_freq': 1,
#    'objective': 'regression',
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 296.16773711882354,
#   'test_rmse': 17.209524604672364,
#   'test_corr_coef': 0.9609747835964374,
#   'pruner': 'MedianPruner'},
#  ('LightGBM', 'NopPruner'): {'best_score': 215.3766207390773,
#   'best_params': {'n_estimators': 300,
#    'learning_rate': 0.05,
#    'num_leaves': 31,
#    'max_depth': 5,
#    'min_child_samples': 1,
#    'subsample': 0.5,
#    'colsample_bytree': 1.0,
#    'reg_alpha': 0,
#    'reg_lambda': 1,
#    'min_child_weight': 0.001,
#    'bagging_freq': 1,
#    'objective': 'regression',
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 215.3766207390773,
#   'test_rmse': 14.675715339944329,
#   'test_corr_coef': 0.9734955910992491,
#   'pruner': 'NopPruner'},
#  ('LightGBM', 'PatientPruner'): {'best_score': 167.35402407134174,
#   'best_params': {'n_estimators': 200,
#    'learning_rate': 0.15,
#    'num_leaves': 31,
#    'max_depth': 3,
#    'min_child_samples': 1,
#    'subsample': 0.5,
#    'colsample_bytree': 1.0,
#    'reg_alpha': 0,
#    'reg_lambda': 0.1,
#    'min_child_weight': 1e-05,
#    'bagging_freq': 1,
#    'objective': 'regression',
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 167.35402407134174,
#   'test_rmse': 12.936538334165819,
#   'test_corr_coef': 0.9745954785310634,
#   'pruner': 'PatientPruner'},
#  ('LightGBM', 'PercentilePruner'): {'best_score': 293.8650080291949,
#   'best_params': {'n_estimators': 300,
#    'learning_rate': 0.05,
#    'num_leaves': 63,
#    'max_depth': 3,
#    'min_child_samples': 5,
#    'subsample': 1.0,
#    'colsample_bytree': 0.7,
#    'reg_alpha': 0.01,
#    'reg_lambda': 0,
#    'min_child_weight': 1e-05,
#    'bagging_freq': 5,
#    'objective': 'regression',
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 293.8650080291949,
#   'test_rmse': 17.142491301709764,
#   'test_corr_coef': 0.9611865496667292,
#   'pruner': 'PercentilePruner'},
#  ('LightGBM', 'SuccessiveHalvingPruner'): {'best_score': 275.3093325558832,
#   'best_params': {'n_estimators': 400,
#    'learning_rate': 0.15,
#    'num_leaves': 63,
#    'max_depth': 3,
#    'min_child_samples': 1,
#    'subsample': 0.5,
#    'colsample_bytree': 0.9,
#    'reg_alpha': 0.1,
#    'reg_lambda': 1,
#    'min_child_weight': 1e-05,
#    'bagging_freq': 1,
#    'objective': 'regression',
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 275.3093325558832,
#   'test_rmse': 16.59244805795345,
#   'test_corr_coef': 0.9620427695672663,
#   'pruner': 'SuccessiveHalvingPruner'},
#  ('LightGBM', 'HyperbandPruner'): {'best_score': 209.74374926478094,
#   'best_params': {'n_estimators': 400,
#    'learning_rate': 0.05,
#    'num_leaves': 15,
#    'max_depth': -1,
#    'min_child_samples': 1,
#    'subsample': 0.5,
#    'colsample_bytree': 1.0,
#    'reg_alpha': 0,
#    'reg_lambda': 1,
#    'min_child_weight': 1e-05,
#    'bagging_freq': 1,
#    'objective': 'regression',
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 209.74374926478094,
#   'test_rmse': 14.482532557007456,
#   'test_corr_coef': 0.9738477399976019,
#   'pruner': 'HyperbandPruner'},
#  ('LightGBM', 'ThresholdPruner'): {'best_score': 212.94153243462407,
#   'best_params': {'n_estimators': 400,
#    'learning_rate': 0.1,
#    'num_leaves': 63,
#    'max_depth': 7,
#    'min_child_samples': 1,
#    'subsample': 0.5,
#    'colsample_bytree': 1.0,
#    'reg_alpha': 0.01,
#    'reg_lambda': 1,
#    'min_child_weight': 1e-05,
#    'bagging_freq': 1,
#    'objective': 'regression',
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 212.94153243462407,
#   'test_rmse': 14.592516316065028,
#   'test_corr_coef': 0.9711176500321567,
#   'pruner': 'ThresholdPruner'},
#  ('LightGBM', 'WilcoxonPruner'): {'best_score': 252.41294416148253,
#   'best_params': {'n_estimators': 400,
#    'learning_rate': 0.15,
#    'num_leaves': 63,
#    'max_depth': 3,
#    'min_child_samples': 1,
#    'subsample': 0.6,
#    'colsample_bytree': 0.7,
#    'reg_alpha': 0.01,
#    'reg_lambda': 0,
#    'min_child_weight': 0.1,
#    'bagging_freq': 1,
#    'objective': 'regression',
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 252.41294416148253,
#   'test_rmse': 15.887509060941005,
#   'test_corr_coef': 0.9627803015534268,
#   'pruner': 'WilcoxonPruner'},
#  ('GPBoost', 'MedianPruner'): {'best_score': 302.4539295475795,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.15,
#    'max_depth': 3,
#    'num_leaves': 31,
#    'min_child_samples': 5,
#    'subsample': 0.5,
#    'colsample_bytree': 0.7,
#    'reg_alpha': 1.0,
#    'reg_lambda': 0.5,
#    'min_child_weight': 1e-05,
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 302.4539295475795,
#   'test_rmse': 17.391202648108596,
#   'test_corr_coef': 0.9600726743566298,
#   'pruner': 'MedianPruner'},
#  ('GPBoost', 'NopPruner'): {'best_score': 318.42534401423444,
#   'best_params': {'n_estimators': 400,
#    'learning_rate': 0.1,
#    'max_depth': 5,
#    'num_leaves': 15,
#    'min_child_samples': 5,
#    'subsample': 1.0,
#    'colsample_bytree': 0.7,
#    'reg_alpha': 0.1,
#    'reg_lambda': 0.1,
#    'min_child_weight': 0.001,
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 318.42534401423444,
#   'test_rmse': 17.844476568793898,
#   'test_corr_coef': 0.9577871307865051,
#   'pruner': 'NopPruner'},
#  ('GPBoost', 'PatientPruner'): {'best_score': 301.8837684766541,
#   'best_params': {'n_estimators': 200,
#    'learning_rate': 0.15,
#    'max_depth': 3,
#    'num_leaves': 31,
#    'min_child_samples': 5,
#    'subsample': 0.9,
#    'colsample_bytree': 0.7,
#    'reg_alpha': 0.5,
#    'reg_lambda': 1.0,
#    'min_child_weight': 0.01,
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 301.8837684766541,
#   'test_rmse': 17.374802688855322,
#   'test_corr_coef': 0.9606103230320533,
#   'pruner': 'PatientPruner'},
#  ('GPBoost', 'PercentilePruner'): {'best_score': 289.62136754581115,
#   'best_params': {'n_estimators': 400,
#    'learning_rate': 0.05,
#    'max_depth': 3,
#    'num_leaves': 31,
#    'min_child_samples': 5,
#    'subsample': 1.0,
#    'colsample_bytree': 0.9,
#    'reg_alpha': 0,
#    'reg_lambda': 0,
#    'min_child_weight': 1e-05,
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 289.62136754581115,
#   'test_rmse': 17.018265703232252,
#   'test_corr_coef': 0.9616429547621224,
#   'pruner': 'PercentilePruner'},
#  ('GPBoost', 'SuccessiveHalvingPruner'): {'best_score': 291.3976432243806,
#   'best_params': {'n_estimators': 200,
#    'learning_rate': 0.15,
#    'max_depth': 3,
#    'num_leaves': 31,
#    'min_child_samples': 5,
#    'subsample': 1.0,
#    'colsample_bytree': 0.7,
#    'reg_alpha': 0.1,
#    'reg_lambda': 0,
#    'min_child_weight': 1e-05,
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 291.3976432243806,
#   'test_rmse': 17.070373259667775,
#   'test_corr_coef': 0.9602353463338138,
#   'pruner': 'SuccessiveHalvingPruner'},
#  ('GPBoost', 'HyperbandPruner'): {'best_score': 301.8639659290113,
#   'best_params': {'n_estimators': 200,
#    'learning_rate': 0.1,
#    'max_depth': 3,
#    'num_leaves': 31,
#    'min_child_samples': 5,
#    'subsample': 1.0,
#    'colsample_bytree': 1.0,
#    'reg_alpha': 0.5,
#    'reg_lambda': 0.1,
#    'min_child_weight': 0.01,
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 301.8639659290113,
#   'test_rmse': 17.37423281555221,
#   'test_corr_coef': 0.9598904538371217,
#   'pruner': 'HyperbandPruner'},
#  ('GPBoost', 'ThresholdPruner'): {'best_score': 291.7690052454734,
#   'best_params': {'n_estimators': 300,
#    'learning_rate': 0.15,
#    'max_depth': 3,
#    'num_leaves': 63,
#    'min_child_samples': 5,
#    'subsample': 0.7,
#    'colsample_bytree': 1.0,
#    'reg_alpha': 0.5,
#    'reg_lambda': 0,
#    'min_child_weight': 1e-05,
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 291.7690052454734,
#   'test_rmse': 17.081247180621016,
#   'test_corr_coef': 0.9628685814302016,
#   'pruner': 'ThresholdPruner'},
#  ('GPBoost', 'WilcoxonPruner'): {'best_score': 309.8384756819266,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.1,
#    'max_depth': 3,
#    'num_leaves': 63,
#    'min_child_samples': 5,
#    'subsample': 1.0,
#    'colsample_bytree': 0.9,
#    'reg_alpha': 0.1,
#    'reg_lambda': 0.5,
#    'min_child_weight': 0.001,
#    'random_state': 42,
#    'n_jobs': -1,
#    'verbose': -1},
#   'test_mse': 309.8384756819266,
#   'test_rmse': 17.60222928159745,
#   'test_corr_coef': 0.9576966752619608,
#   'pruner': 'WilcoxonPruner'},
#  ('CatBoost', 'MedianPruner'): {'best_score': 383.597014990092,
#   'best_params': {'iterations': 1000,
#    'learning_rate': 0.1,
#    'depth': 4,
#    'l2_leaf_reg': 9,
#    'border_count': 128,
#    'min_data_in_leaf': 1,
#    'rsm': 0.6,
#    'bagging_temperature': 1,
#    'random_seed': 42,
#    'verbose': 0},
#   'test_mse': 383.597014990092,
#   'test_rmse': 19.585632871829596,
#   'test_corr_coef': 0.9504320068494378,
#   'pruner': 'MedianPruner'},
#  ('CatBoost', 'NopPruner'): {'best_score': 347.4429012205738,
#   'best_params': {'iterations': 1000,
#    'learning_rate': 0.03,
#    'depth': 4,
#    'l2_leaf_reg': 5,
#    'border_count': 32,
#    'min_data_in_leaf': 20,
#    'rsm': 0.6,
#    'bagging_temperature': 10,
#    'random_seed': 42,
#    'verbose': 0},
#   'test_mse': 347.4429012205738,
#   'test_rmse': 18.63982031084457,
#   'test_corr_coef': 0.9614771149420601,
#   'pruner': 'NopPruner'},
#  ('CatBoost', 'PatientPruner'): {'best_score': 381.4352001178893,
#   'best_params': {'iterations': 200,
#    'learning_rate': 0.1,
#    'depth': 4,
#    'l2_leaf_reg': 3,
#    'border_count': 128,
#    'min_data_in_leaf': 5,
#    'rsm': 0.8,
#    'bagging_temperature': 1,
#    'random_seed': 42,
#    'verbose': 0},
#   'test_mse': 381.4352001178893,
#   'test_rmse': 19.530366103017354,
#   'test_corr_coef': 0.9571259157623251,
#   'pruner': 'PatientPruner'},
#  ('CatBoost', 'PercentilePruner'): {'best_score': 352.7919134205213,
#   'best_params': {'iterations': 1000,
#    'learning_rate': 0.05,
#    'depth': 4,
#    'l2_leaf_reg': 3,
#    'border_count': 32,
#    'min_data_in_leaf': 1,
#    'rsm': 0.8,
#    'bagging_temperature': 0,
#    'random_seed': 42,
#    'verbose': 0},
#   'test_mse': 352.7919134205213,
#   'test_rmse': 18.782755746176367,
#   'test_corr_coef': 0.9609618632008907,
#   'pruner': 'PercentilePruner'},
#  ('CatBoost', 'SuccessiveHalvingPruner'): {'best_score': 376.2222721954891,
#   'best_params': {'iterations': 1000,
#    'learning_rate': 0.05,
#    'depth': 4,
#    'l2_leaf_reg': 3,
#    'border_count': 128,
#    'min_data_in_leaf': 20,
#    'rsm': 0.6,
#    'bagging_temperature': 10,
#    'random_seed': 42,
#    'verbose': 0},
#   'test_mse': 376.2222721954891,
#   'test_rmse': 19.39644998950811,
#   'test_corr_coef': 0.9536838656258818,
#   'pruner': 'SuccessiveHalvingPruner'},
#  ('CatBoost', 'HyperbandPruner'): {'best_score': 352.7919134205213,
#   'best_params': {'iterations': 1000,
#    'learning_rate': 0.05,
#    'depth': 4,
#    'l2_leaf_reg': 3,
#    'border_count': 32,
#    'min_data_in_leaf': 1,
#    'rsm': 0.8,
#    'bagging_temperature': 0,
#    'random_seed': 42,
#    'verbose': 0},
#   'test_mse': 352.7919134205213,
#   'test_rmse': 18.782755746176367,
#   'test_corr_coef': 0.9609618632008907,
#   'pruner': 'HyperbandPruner'},
#  ('CatBoost', 'ThresholdPruner'): {'best_score': 364.6500962303509,
#   'best_params': {'iterations': 1000,
#    'learning_rate': 0.1,
#    'depth': 4,
#    'l2_leaf_reg': 7,
#    'border_count': 32,
#    'min_data_in_leaf': 1,
#    'rsm': 0.8,
#    'bagging_temperature': 1,
#    'random_seed': 42,
#    'verbose': 0},
#   'test_mse': 364.6500962303509,
#   'test_rmse': 19.09581357864469,
#   'test_corr_coef': 0.9615043644058586,
#   'pruner': 'ThresholdPruner'},
#  ('CatBoost', 'WilcoxonPruner'): {'best_score': 363.24580555149436,
#   'best_params': {'iterations': 1000,
#    'learning_rate': 0.03,
#    'depth': 4,
#    'l2_leaf_reg': 7,
#    'border_count': 128,
#    'min_data_in_leaf': 5,
#    'rsm': 0.8,
#    'bagging_temperature': 1,
#    'random_seed': 42,
#    'verbose': 0},
#   'test_mse': 363.24580555149436,
#   'test_rmse': 19.05900851438748,
#   'test_corr_coef': 0.9612932773075077,
#   'pruner': 'WilcoxonPruner'},
#  ('NGBoost', 'MedianPruner'): {'best_score': 208.6206854916466,
#   'best_params': {'n_estimators': 200,
#    'learning_rate': 0.05,
#    'natural_gradient': True,
#    'minibatch_frac': 0.5,
#    'col_sample': 0.7,
#    'Dist': ngboost.distns.normal.Normal,
#    'Score': ngboost.scores.LogScore,
#    'random_state': 42,
#    'verbose': 0},
#   'test_mse': 208.6206854916466,
#   'test_rmse': 14.443707470440081,
#   'test_corr_coef': 0.972322539208482,
#   'pruner': 'MedianPruner'},
#  ('NGBoost', 'NopPruner'): {'best_score': 220.97018702137282,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.01,
#    'natural_gradient': True,
#    'minibatch_frac': 0.5,
#    'col_sample': 0.9,
#    'Dist': ngboost.distns.normal.Normal,
#    'Score': ngboost.scores.LogScore,
#    'random_state': 42,
#    'verbose': 0},
#   'test_mse': 220.97018702137282,
#   'test_rmse': 14.865065994517913,
#   'test_corr_coef': 0.9723792362495827,
#   'pruner': 'NopPruner'},
#  ('NGBoost', 'PatientPruner'): {'best_score': 192.560849013683,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.01,
#    'natural_gradient': True,
#    'minibatch_frac': 0.5,
#    'col_sample': 1.0,
#    'Dist': ngboost.distns.normal.Normal,
#    'Score': ngboost.scores.LogScore,
#    'random_state': 42,
#    'verbose': 0},
#   'test_mse': 192.560849013683,
#   'test_rmse': 13.876629598489792,
#   'test_corr_coef': 0.9752386717656648,
#   'pruner': 'PatientPruner'},
#  ('NGBoost', 'PercentilePruner'): {'best_score': 238.07413166136223,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.03,
#    'natural_gradient': True,
#    'minibatch_frac': 0.5,
#    'col_sample': 0.9,
#    'Dist': ngboost.distns.normal.Normal,
#    'Score': ngboost.scores.LogScore,
#    'random_state': 42,
#    'verbose': 0},
#   'test_mse': 238.07413166136223,
#   'test_rmse': 15.429651054426417,
#   'test_corr_coef': 0.9681571443145065,
#   'pruner': 'PercentilePruner'},
#  ('NGBoost', 'SuccessiveHalvingPruner'): {'best_score': 205.8348672055246,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.01,
#    'natural_gradient': True,
#    'minibatch_frac': 0.5,
#    'col_sample': 1.0,
#    'Dist': ngboost.distns.normal.Normal,
#    'Score': ngboost.scores.LogScore,
#    'random_state': 42,
#    'verbose': 0},
#   'test_mse': 205.8348672055246,
#   'test_rmse': 14.346946267604288,
#   'test_corr_coef': 0.9737618718364464,
#   'pruner': 'SuccessiveHalvingPruner'},
#  ('NGBoost', 'HyperbandPruner'): {'best_score': 217.94197670619747,
#   'best_params': {'n_estimators': 1000,
#    'learning_rate': 0.01,
#    'natural_gradient': True,
#    'minibatch_frac': 0.5,
#    'col_sample': 0.7,
#    'Dist': ngboost.distns.normal.Normal,
#    'Score': ngboost.scores.LogScore,
#    'random_state': 42,
#    'verbose': 0},
#   'test_mse': 217.94197670619747,
#   'test_rmse': 14.762858012803532,
#   'test_corr_coef': 0.9709712414950974,
#   'pruner': 'HyperbandPruner'},
#  ('NGBoost', 'ThresholdPruner'): {'best_score': 192.70590804151243,
#   'best_params': {'n_estimators': 1000,
#    'learning_rate': 0.01,
#    'natural_gradient': True,
#    'minibatch_frac': 0.5,
#    'col_sample': 0.9,
#    'Dist': ngboost.distns.normal.Normal,
#    'Score': ngboost.scores.LogScore,
#    'random_state': 42,
#    'verbose': 0},
#   'test_mse': 192.70590804151243,
#   'test_rmse': 13.881855352996315,
#   'test_corr_coef': 0.9745085372253655,
#   'pruner': 'ThresholdPruner'},
#  ('NGBoost', 'WilcoxonPruner'): {'best_score': 181.73374322211725,
#   'best_params': {'n_estimators': 1000,
#    'learning_rate': 0.01,
#    'natural_gradient': True,
#    'minibatch_frac': 0.5,
#    'col_sample': 1.0,
#    'Dist': ngboost.distns.normal.Normal,
#    'Score': ngboost.scores.LogScore,
#    'random_state': 42,
#    'verbose': 0},
#   'test_mse': 181.73374322211725,
#   'test_rmse': 13.480865818711989,
#   'test_corr_coef': 0.9768919590123354,
#   'pruner': 'WilcoxonPruner'},
#  ('HistGradientBoosting', 'MedianPruner'): {'best_score': 306.9466510692115,
#   'best_params': {'learning_rate': 0.1,
#    'max_iter': 300,
#    'max_depth': 3,
#    'min_samples_leaf': 5,
#    'max_leaf_nodes': 31,
#    'l2_regularization': 0.5,
#    'max_bins': 128,
#    'early_stopping': False,
#    'validation_fraction': 0.1,
#    'n_iter_no_change': 5,
#    'loss': 'squared_error',
#    'random_state': 42,
#    'verbose': 0},
#   'test_mse': 306.9466510692115,
#   'test_rmse': 17.5198930096394,
#   'test_corr_coef': 0.9571560877136178,
#   'pruner': 'MedianPruner'},
#  ('HistGradientBoosting', 'NopPruner'): {'best_score': 309.71048974232986,
#   'best_params': {'learning_rate': 0.15,
#    'max_iter': 100,
#    'max_depth': 3,
#    'min_samples_leaf': 5,
#    'max_leaf_nodes': 15,
#    'l2_regularization': 0.5,
#    'max_bins': 255,
#    'early_stopping': False,
#    'validation_fraction': 0.2,
#    'n_iter_no_change': 5,
#    'loss': 'squared_error',
#    'random_state': 42,
#    'verbose': 0},
#   'test_mse': 309.71048974232986,
#   'test_rmse': 17.598593402381052,
#   'test_corr_coef': 0.9582676889706158,
#   'pruner': 'NopPruner'},
#  ('HistGradientBoosting', 'PatientPruner'): {'best_score': 305.50458250552157,
#   'best_params': {'learning_rate': 0.1,
#    'max_iter': 200,
#    'max_depth': 3,
#    'min_samples_leaf': 5,
#    'max_leaf_nodes': 15,
#    'l2_regularization': 0.5,
#    'max_bins': 255,
#    'early_stopping': False,
#    'validation_fraction': 0.1,
#    'n_iter_no_change': 10,
#    'loss': 'squared_error',
#    'random_state': 42,
#    'verbose': 0},
#   'test_mse': 305.50458250552157,
#   'test_rmse': 17.478689381802102,
#   'test_corr_coef': 0.957444692058178,
#   'pruner': 'PatientPruner'},
#  ('HistGradientBoosting',
#   'PercentilePruner'): {'best_score': 336.1044050556328, 'best_params': {'learning_rate': 0.15,
#    'max_iter': 200,
#    'max_depth': 7,
#    'min_samples_leaf': 5,
#    'max_leaf_nodes': 15,
#    'l2_regularization': 0.1,
#    'max_bins': 128,
#    'early_stopping': False,
#    'validation_fraction': 0.1,
#    'n_iter_no_change': 5,
#    'loss': 'squared_error',
#    'random_state': 42,
#    'verbose': 0}, 'test_mse': 336.1044050556328, 'test_rmse': 18.333150439998924, 'test_corr_coef': 0.9541352668559412, 'pruner': 'PercentilePruner'},
#  ('HistGradientBoosting',
#   'SuccessiveHalvingPruner'): {'best_score': 310.15497272579285, 'best_params': {'learning_rate': 0.15,
#    'max_iter': 200,
#    'max_depth': 3,
#    'min_samples_leaf': 5,
#    'max_leaf_nodes': 15,
#    'l2_regularization': 0.5,
#    'max_bins': 64,
#    'early_stopping': False,
#    'validation_fraction': 0.2,
#    'n_iter_no_change': 5,
#    'loss': 'squared_error',
#    'random_state': 42,
#    'verbose': 0}, 'test_mse': 310.15497272579285, 'test_rmse': 17.611217241457016, 'test_corr_coef': 0.9578779385722576, 'pruner': 'SuccessiveHalvingPruner'},
#  ('HistGradientBoosting',
#   'HyperbandPruner'): {'best_score': 310.15497272579285, 'best_params': {'learning_rate': 0.15,
#    'max_iter': 200,
#    'max_depth': 3,
#    'min_samples_leaf': 5,
#    'max_leaf_nodes': None,
#    'l2_regularization': 0.5,
#    'max_bins': 255,
#    'early_stopping': False,
#    'validation_fraction': 0.1,
#    'n_iter_no_change': 15,
#    'loss': 'squared_error',
#    'random_state': 42,
#    'verbose': 0}, 'test_mse': 310.15497272579285, 'test_rmse': 17.611217241457016, 'test_corr_coef': 0.9578779385722576, 'pruner': 'HyperbandPruner'},
#  ('HistGradientBoosting', 'ThresholdPruner'): {'best_score': 308.0584051247876,
#   'best_params': {'learning_rate': 0.1,
#    'max_iter': 400,
#    'max_depth': 3,
#    'min_samples_leaf': 5,
#    'max_leaf_nodes': 15,
#    'l2_regularization': 1.0,
#    'max_bins': 128,
#    'early_stopping': False,
#    'validation_fraction': 0.2,
#    'n_iter_no_change': 5,
#    'loss': 'squared_error',
#    'random_state': 42,
#    'verbose': 0},
#   'test_mse': 308.0584051247876,
#   'test_rmse': 17.551592666330528,
#   'test_corr_coef': 0.9571352264254247,
#   'pruner': 'ThresholdPruner'},
#  ('HistGradientBoosting', 'WilcoxonPruner'): {'best_score': 308.2494075545725,
#   'best_params': {'learning_rate': 0.1,
#    'max_iter': 500,
#    'max_depth': 3,
#    'min_samples_leaf': 5,
#    'max_leaf_nodes': 31,
#    'l2_regularization': 1.0,
#    'max_bins': 64,
#    'early_stopping': False,
#    'validation_fraction': 0.2,
#    'n_iter_no_change': 5,
#    'loss': 'squared_error',
#    'random_state': 42,
#    'verbose': 0},
#   'test_mse': 308.2494075545725,
#   'test_rmse': 17.55703299406174,
#   'test_corr_coef': 0.9571023046674804,
#   'pruner': 'WilcoxonPruner'},
#  ('PGBM', 'MedianPruner'): {'best_score': 992.4083411512967,
#   'best_params': {'n_estimators': 200,
#    'learning_rate': 0.01,
#    'max_leaves': 38,
#    'min_split_gain': 0.0,
#    'reg_lambda': 0.1,
#    'feature_fraction': 0.9,
#    'bagging_fraction': 0.9,
#    'tree_correlation': 0.3,
#    'min_data_in_leaf': 10,
#    'max_bin': 128,
#    'distribution': 'laplace'},
#   'test_mse': 992.4083411512967,
#   'test_rmse': 31.502513251347054,
#   'test_corr_coef': 0.894616031534982,
#   'pruner': 'MedianPruner'},
#  ('PGBM', 'NopPruner'): {'best_score': 340.38650817195673,
#   'best_params': {'n_estimators': 200,
#    'learning_rate': 0.1,
#    'max_leaves': 50,
#    'min_split_gain': 1.0,
#    'reg_lambda': 1.0,
#    'feature_fraction': 0.7,
#    'bagging_fraction': 1.0,
#    'tree_correlation': 0.3,
#    'min_data_in_leaf': 5,
#    'max_bin': 64,
#    'distribution': 'normal'},
#   'test_mse': 340.38650817195673,
#   'test_rmse': 18.449566612036087,
#   'test_corr_coef': 0.9562660706401699,
#   'pruner': 'NopPruner'},
#  ('PGBM', 'PatientPruner'): {'best_score': 3051.0402161071343,
#   'best_params': {'n_estimators': 200,
#    'learning_rate': 0.1,
#    'max_leaves': 44,
#    'min_split_gain': 0.1,
#    'reg_lambda': 0.1,
#    'feature_fraction': 0.5,
#    'bagging_fraction': 0.7,
#    'tree_correlation': 0.0,
#    'min_data_in_leaf': 20,
#    'max_bin': 256,
#    'distribution': 'normal'},
#   'test_mse': 3051.0402161071343,
#   'test_rmse': 55.236221957218746,
#   'test_corr_coef': 0.5650411148664678,
#   'pruner': 'PatientPruner'},
#  ('PGBM', 'PercentilePruner'): {'best_score': 591.6333154026611,
#   'best_params': {'n_estimators': 200,
#    'learning_rate': 0.15,
#    'max_leaves': 32,
#    'min_split_gain': 1.0,
#    'reg_lambda': 0.1,
#    'feature_fraction': 0.5,
#    'bagging_fraction': 1.0,
#    'tree_correlation': 0.1,
#    'min_data_in_leaf': 10,
#    'max_bin': 64,
#    'distribution': 'normal'},
#   'test_mse': 591.6333154026611,
#   'test_rmse': 24.32351363192952,
#   'test_corr_coef': 0.9100557818341837,
#   'pruner': 'PercentilePruner'},
#  ('PGBM', 'SuccessiveHalvingPruner'): {'best_score': 1579.8616374247686,
#   'best_params': {'n_estimators': 500,
#    'learning_rate': 0.01,
#    'max_leaves': 30,
#    'min_split_gain': 1.0,
#    'reg_lambda': 1.0,
#    'feature_fraction': 1.0,
#    'bagging_fraction': 0.9,
#    'tree_correlation': 0.2,
#    'min_data_in_leaf': 20,
#    'max_bin': 64,
#    'distribution': 'laplace'},
#   'test_mse': 1579.8616374247686,
#   'test_rmse': 39.74747334642503,
#   'test_corr_coef': 0.7520550146554843,
#   'pruner': 'SuccessiveHalvingPruner'},
#  ('PGBM', 'HyperbandPruner'): {'best_score': 572.1861646272821,
#   'best_params': {'n_estimators': 300,
#    'learning_rate': 0.05,
#    'max_leaves': 21,
#    'min_split_gain': 0.0,
#    'reg_lambda': 0.1,
#    'feature_fraction': 0.7,
#    'bagging_fraction': 0.9,
#    'tree_correlation': 0.3,
#    'min_data_in_leaf': 10,
#    'max_bin': 128,
#    'distribution': 'studentt'},
#   'test_mse': 572.1861646272821,
#   'test_rmse': 23.920413136634618,
#   'test_corr_coef': 0.913693102401316,
#   'pruner': 'HyperbandPruner'},
#  ('PGBM', 'ThresholdPruner'): {'best_score': 262.60126970395567,
#   'best_params': {'n_estimators': 100,
#    'learning_rate': 0.1,
#    'max_leaves': 47,
#    'min_split_gain': 0.0,
#    'reg_lambda': 1.0,
#    'feature_fraction': 0.9,
#    'bagging_fraction': 0.5,
#    'tree_correlation': 0.3,
#    'min_data_in_leaf': 3,
#    'max_bin': 128,
#    'distribution': 'laplace'},
#   'test_mse': 262.60126970395567,
#   'test_rmse': 16.204976695569655,
#   'test_corr_coef': 0.9605348672424883,
#   'pruner': 'ThresholdPruner'},
#  ('PGBM', 'WilcoxonPruner'): {'best_score': 583.1855919476949,
#   'best_params': {'n_estimators': 200,
#    'learning_rate': 0.05,
#    'max_leaves': 42,
#    'min_split_gain': 0.1,
#    'reg_lambda': 5.0,
#    'feature_fraction': 1.0,
#    'bagging_fraction': 1.0,
#    'tree_correlation': 0.3,
#    'min_data_in_leaf': 10,
#    'max_bin': 128,
#    'distribution': 'normal'},
#   'test_mse': 583.1855919476949,
#   'test_rmse': 24.149235846040654,
#   'test_corr_coef': 0.916358980778455,
#   'pruner': 'WilcoxonPruner'}}

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
plot_best_scores(best_scores_autosampler,"./drive/MyDrive/water_analysis/test_results.xlsx")

# %%
generate_interpretml_explanations_summary_pruners(best_scores_autosampler, X_train, y_train, x_test, feature_names,excel_file_path = "./drive/MyDrive/water_analysis/test_results.xlsx")
# Out:
#   0%|          | 0/47 [00:00<?, ?it/s]
# Created a new Excel file at: ./drive/MyDrive/water_analysis/test_results.xlsx
#   0%|          | 0/47 [00:00<?, ?it/s]
#   0%|          | 0/47 [00:00<?, ?it/s]
#   0%|          | 0/47 [00:00<?, ?it/s]
#   0%|          | 0/47 [00:00<?, ?it/s]
#   0%|          | 0/47 [00:00<?, ?it/s]
#   0%|          | 0/47 [00:00<?, ?it/s]
# Model HistGradientBoosting is not supported or not available.
# Model PGBM is not supported or not available.

# %% [markdown]
# # **Best Model Analysis**

# %%
def get_best_models_and_predict(best_scores_autosampler, X_train, y_train, X_test, y_test, file_path):
    # Convert input data to NumPy arrays
    X_train = np.array(X_train)
    y_train = np.array(y_train)
    X_test = np.array(X_test)
    y_test = np.array(y_test)

    # Mapping for model creation based on dictionary keys
    model_mapping = {
        'Random Forest': RandomForestRegressor,
        'Gradient Boosting': GradientBoostingRegressor,
        'XGBoost': XGBRegressor,
        'LightGBM': LGBMRegressor,
        'CatBoost': CatBoostRegressor,
        'GPBoost': GPBoostRegressor,
        'NGBoost': NGBRegressor,
        'HistGradientBoosting': HistGradientBoostingRegressor,
        'PGBM': PGBM  # PGBM is handled separately
    }
    def mseloss_objective(yhat, y, sample_weight=None):
        if not torch.is_tensor(yhat):
            yhat = torch.from_numpy(np.array(yhat)).float()
        if not torch.is_tensor(y):
            y = torch.from_numpy(np.array(y)).float()
        gradient = yhat - y
        hessian = torch.ones_like(yhat)
        return gradient, hessian

    def rmseloss_metric(yhat, y, sample_weight=None):
        if not torch.is_tensor(yhat):
            yhat = torch.from_numpy(np.array(yhat)).float()
        if not torch.is_tensor(y):
            y = torch.from_numpy(np.array(y)).float()
        loss = torch.sqrt(torch.mean((yhat - y) ** 2))
        return loss

    # Dictionary to store the best model for each type
    best_models = {}

    # Iterate over the dictionary to find the best pruner for each model type
    for (model_name, pruner), params in best_scores_autosampler.items():
        current_score = params.get('test_mse', np.inf)
        if model_name not in best_models or current_score < best_models[model_name]['score']:
            best_models[model_name] = {
                'score': current_score,
                'params': params['best_params'],
                'pruner': pruner
            }

    # Prepare a DataFrame to store predictions
    df = pd.read_csv(file_path)

    # Iterate over the best models to train and predict
    for model_name, model_info in best_models.items():
        best_params = model_info['params']
        model_class = model_mapping.get(model_name)

        if model_class is None:
            print(f"Model {model_name} is not supported or not available.")
            continue

        # Handle specific parameters or settings for model if needed
        if model_name == 'CatBoost':
            best_params.pop('verbose', None)  # Remove 'verbose' for CatBoost

        # Create an instance of the best model with the best parameters
        if model_name == 'PGBM':
            model = model_class()
            model.train((X_train, y_train), objective=mseloss_objective, metric=rmseloss_metric, params=best_params)
            predictions = model.predict(X_test)
        else:
            model = model_class(**best_params)
            model.fit(X_train, y_train)
            predictions = model.predict(X_test)

        # Add predictions to the DataFrame
        df[f'{model_name} Predictions'] = predictions

        # Plot actual vs. predicted
        plt.figure(figsize=(10, 6))
        plt.scatter(y_test, predictions, alpha=0.6)
        plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', color='red', lw=2)
        plt.xlabel("Actual")
        plt.ylabel("Predicted")
        plt.title(f"Actual vs. Predicted Values ({model_name})")
        plt.grid(True)
        plt.tight_layout()

        # Save the plot temporarily
        plot_path = f'temp_plot_{model_name}.png'
        plt.savefig(plot_path)
        plt.close()

    # Save predictions and plots to Excel
    with pd.ExcelWriter(file_path.replace('.csv', '_results.xlsx'), engine='xlsxwriter') as writer:
        # Write data to Excel
        df.to_excel(writer, sheet_name='Data', index=False)

        # Get the xlsxwriter objects
        workbook = writer.book

        # Insert each plot into a separate worksheet
        for model_name in best_models.keys():
            # Shorten the worksheet name to fit within Excel's 31 character limit
            short_model_name = ''.join([word[0] for word in model_name.split()])  # e.g., 'RF' for 'Random Forest'
            sheet_name = f'{short_model_name}_Plot'

            worksheet = workbook.add_worksheet(sheet_name)
            writer.sheets[sheet_name] = worksheet
            plot_path = f'temp_plot_{model_name}.png'
            worksheet.insert_image('A1', plot_path)

    # Clean up temporary plot files
    for model_name in best_models.keys():
        os.remove(f'temp_plot_{model_name}.png')

    return df, best_models

# Call the function
df, best_models = get_best_models_and_predict(best_scores_autosampler, X_train, y_train, X_test, y_test, "./drive/MyDrive/water_analysis/test1.csv")
# Out:
# 971:	learn: 0.6805882	total: 184ms	remaining: 5.29ms
# 972:	learn: 0.6761460	total: 184ms	remaining: 5.1ms
# 973:	learn: 0.6741789	total: 184ms	remaining: 4.91ms
# 974:	learn: 0.6723917	total: 184ms	remaining: 4.72ms
# 975:	learn: 0.6715036	total: 184ms	remaining: 4.53ms
# 976:	learn: 0.6675273	total: 184ms	remaining: 4.34ms
# 977:	learn: 0.6664948	total: 185ms	remaining: 4.15ms
# 978:	learn: 0.6648490	total: 185ms	remaining: 3.96ms
# 979:	learn: 0.6643631	total: 185ms	remaining: 3.77ms
# 980:	learn: 0.6633062	total: 185ms	remaining: 3.59ms
# 981:	learn: 0.6615557	total: 185ms	remaining: 3.4ms
# 982:	learn: 0.6585554	total: 186ms	remaining: 3.21ms
# 983:	learn: 0.6554968	total: 186ms	remaining: 3.02ms
# 984:	learn: 0.6523242	total: 186ms	remaining: 2.83ms
# 985:	learn: 0.6515214	total: 186ms	remaining: 2.64ms
# 986:	learn: 0.6508083	total: 186ms	remaining: 2.45ms
# 987:	learn: 0.6473758	total: 187ms	remaining: 2.27ms
# 988:	learn: 0.6466009	total: 187ms	remaining: 2.08ms
# 989:	learn: 0.6456505	total: 187ms	remaining: 1.89ms
# 990:	learn: 0.6424992	total: 187ms	remaining: 1.7ms
# 991:	learn: 0.6382633	total: 187ms	remaining: 1.51ms
# 992:	learn: 0.6352429	total: 187ms	remaining: 1.32ms
# 993:	learn: 0.6338949	total: 188ms	remaining: 1.13ms
# 994:	learn: 0.6310267	total: 188ms	remaining: 943us
# 995:	learn: 0.6301863	total: 188ms	remaining: 754us
# 996:	learn: 0.6271160	total: 188ms	remaining: 565us
# 997:	learn: 0.6262990	total: 188ms	remaining: 377us
# 998:	learn: 0.6233177	total: 188ms	remaining: 188us
# 999:	learn: 0.6207070	total: 189ms	remaining: 0us
# Training on CPU
# Estimator 0/100, Train metric: 53.3198
# Estimator 1/100, Train metric: 50.1704
# Estimator 2/100, Train metric: 47.7832
# Estimator 3/100, Train metric: 44.5194
# Estimator 4/100, Train metric: 41.6251
# Estimator 5/100, Train metric: 38.9817
# Estimator 6/100, Train metric: 37.4275
# Estimator 7/100, Train metric: 35.2612
# Estimator 8/100, Train metric: 34.0276
# Estimator 9/100, Train metric: 31.9482
# Estimator 10/100, Train metric: 30.2254
# Estimator 11/100, Train metric: 28.5519
# Estimator 12/100, Train metric: 27.6122
# Estimator 13/100, Train metric: 26.6317
# Estimator 14/100, Train metric: 25.3513
# Estimator 15/100, Train metric: 23.9114
# Estimator 16/100, Train metric: 23.3696
# Estimator 17/100, Train metric: 22.9672
# Estimator 18/100, Train metric: 22.1373
# Estimator 19/100, Train metric: 21.7580
# Estimator 20/100, Train metric: 21.4500
# Estimator 21/100, Train metric: 21.1727
# Estimator 22/100, Train metric: 20.3884
# Estimator 23/100, Train metric: 20.0420
# Estimator 24/100, Train metric: 19.7254
# Estimator 25/100, Train metric: 18.8651
# Estimator 26/100, Train metric: 17.9492
# Estimator 27/100, Train metric: 17.7780
# Estimator 28/100, Train metric: 17.4432
# Estimator 29/100, Train metric: 16.7042
# Estimator 30/100, Train metric: 16.2943
# Estimator 31/100, Train metric: 15.6944
# Estimator 32/100, Train metric: 15.4083
# Estimator 33/100, Train metric: 14.8349
# Estimator 34/100, Train metric: 14.3306
# Estimator 35/100, Train metric: 13.7644
# Estimator 36/100, Train metric: 13.4740
# Estimator 37/100, Train metric: 13.3863
# Estimator 38/100, Train metric: 13.0706
# Estimator 39/100, Train metric: 12.7706
# Estimator 40/100, Train metric: 12.4866
# Estimator 41/100, Train metric: 12.1417
# Estimator 42/100, Train metric: 11.7666
# Estimator 43/100, Train metric: 11.7779
# Estimator 44/100, Train metric: 11.5704
# Estimator 45/100, Train metric: 11.5677
# Estimator 46/100, Train metric: 11.4048
# Estimator 47/100, Train metric: 11.2999
# Estimator 48/100, Train metric: 11.1247
# Estimator 49/100, Train metric: 11.1146
# Estimator 50/100, Train metric: 10.8307
# Estimator 51/100, Train metric: 10.5143
# Estimator 52/100, Train metric: 10.5762
# Estimator 53/100, Train metric: 10.4562
# Estimator 54/100, Train metric: 10.4316
# Estimator 55/100, Train metric: 10.2248
# Estimator 56/100, Train metric: 10.2107
# Estimator 57/100, Train metric: 10.1210
# Estimator 58/100, Train metric: 9.9219
# Estimator 59/100, Train metric: 9.7239
# Estimator 60/100, Train metric: 9.7102
# Estimator 61/100, Train metric: 9.6112
# Estimator 62/100, Train metric: 9.5036
# Estimator 63/100, Train metric: 9.3699
# Estimator 64/100, Train metric: 9.3705
# Estimator 65/100, Train metric: 9.2170
# Estimator 66/100, Train metric: 8.8572
# Estimator 67/100, Train metric: 8.8548
# Estimator 68/100, Train metric: 8.6880
# Estimator 69/100, Train metric: 8.5660
# Estimator 70/100, Train metric: 8.4318
# Estimator 71/100, Train metric: 8.3326
# Estimator 72/100, Train metric: 8.2678
# Estimator 73/100, Train metric: 8.1295
# Estimator 74/100, Train metric: 8.1313
# Estimator 75/100, Train metric: 8.0716
# Estimator 76/100, Train metric: 7.9787
# Estimator 77/100, Train metric: 7.8701
# Estimator 78/100, Train metric: 7.8880
# Estimator 79/100, Train metric: 7.7581
# Estimator 80/100, Train metric: 7.8031
# Estimator 81/100, Train metric: 7.5601
# Estimator 82/100, Train metric: 7.4438
# Estimator 83/100, Train metric: 7.3612
# Estimator 84/100, Train metric: 7.1685
# Estimator 85/100, Train metric: 7.1801
# Estimator 86/100, Train metric: 7.0151
# Estimator 87/100, Train metric: 6.9793
# Estimator 88/100, Train metric: 6.9474
# Estimator 89/100, Train metric: 6.9183
# Estimator 90/100, Train metric: 6.9023
# Estimator 91/100, Train metric: 6.8091
# Estimator 92/100, Train metric: 6.7193
# Estimator 93/100, Train metric: 6.6850
# Estimator 94/100, Train metric: 6.5879
# Estimator 95/100, Train metric: 6.4983
# Estimator 96/100, Train metric: 6.4828
# Estimator 97/100, Train metric: 6.4484
# Estimator 98/100, Train metric: 6.4092
# Estimator 99/100, Train metric: 6.3532
